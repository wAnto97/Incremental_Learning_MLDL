# %%
# !rm -r 'IncrementalLeraningMLDL'
# !git clone "https://github.com/wAnto97/IncrementalLeraningMLDL"
from IncrementalLeraningMLDL.src.CIFAR100_dataset import MyCIFAR100
from IncrementalLeraningMLDL.src.Utils import Utils
from IncrementalLeraningMLDL.src.MyNet import MyNet
from IncrementalLeraningMLDL.src.Loss import Loss

import numpy as np
import sys
import copy
from torch.backends import cudnn
from torchvision import transforms
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from torch.utils.data import  DataLoader

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Cloning into 'IncrementalLeraningMLDL'...
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 898 (delta 1), reused 7 (delta 1), pack-reused 886
# Receiving objects: 100% (898/898), 10.61 MiB | 21.82 MiB/s, done.
# Resolving deltas: 100% (584/584), done.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %% [markdown]
# **Loading data**

# %%
# Define transforms for training phase
train_transform = transforms.Compose([
                                      transforms.RandomCrop(32, padding=4),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(), # Turn PIL Image to torch.Tensor
                                      transforms.Normalize( (0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))]) # Normalizes tensor with mean and standard deviation

# Define transforms for the evaluation phase
eval_transform = transforms.Compose([
                                      transforms.ToTensor(),
                                      transforms.Normalize( (0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))])

training_set = MyCIFAR100('/content',train=True, n_groups=10, transform=train_transform, download=True)
test_set = MyCIFAR100('/content',train=False, n_groups=10, transform=eval_transform, download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# **Hyperparameters**

# %%
DEVICE = 'cuda' # 'cuda' or 'cpu'  

BATCH_SIZE = 128     # Higher batch sizes allows for larger learning rates. An empirical heuristic suggests that, when changing
                     # the batch strain_dataloaderize, learning rate should change by the same factor to have comparable results
LR = 2     # The initial Learning Rate
MOMENTUM = 0.9       # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 1e-5  # Regularization, you can keep this at the default

NUM_EPOCHS = 70             # Total number of training epochs (iterations over dataset)
STEP_SIZE = [49,63]      # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.2                 # Multiplicative factor for learning rate step-down

LOG_FREQUENCY = 10

CLASSES_PER_GROUP=10
NUM_GROUPS=10

# %% [markdown]
# **Utils function**

# %%
def validation(val_dataloader,net,lwf,conf_matrix=False):
    net.train(False)
    running_corrects = 0
    y_pred = []
    all_labels = []
    tmp_loss=[]
    for images, labels, _ in val_dataloader:

        images = images.to(DEVICE)
        labels = labels.to(DEVICE)

        # Forward Pass
        outputs = net(images)
        # Get predictions
        _, preds = torch.max(outputs.data, 1)
        loss,clf_loss,dist_loss = myLoss.icarl_loss([],outputs,labels,step,-1,utils,CLASSES_PER_GROUP) #current_step = -1 to compute the loss on the validation set
        tmp_loss.append(loss.item())
        # Update Corrects
        running_corrects += torch.sum(preds == labels.data).data.item()
        y_pred += list(map(lambda x : x.item(),preds))
        all_labels += list(labels)

        # Calculate Accuracy
    accuracy = running_corrects / float(len(val_dataloader.dataset))

    if(conf_matrix == True):
        all_labels = list(map(lambda label : label.item(),all_labels))
        return accuracy,confusion_matrix(y_pred,np.array(all_labels))

    return accuracy,np.array(tmp_loss).mean()

# %% [markdown]
# **Main**

# %%
myNet = MyNet(n_classes=CLASSES_PER_GROUP)
utils = Utils()
myLoss = Loss()
typeScheduler = 'plateau'

#Creating dataloader for the first group of 10 classes
train_dataloader,val_dataloader,test_dataloader = utils.create_dataloaders(training_set,test_set,1,BATCH_SIZE)

#Initialize some useful lists
best_train_accuracies = []
best_val_accuracies = []
best_test_accuracies = []
losses_train_all = []
old_outputs=[]

for i in range(NUM_GROUPS):
    best_val_accuracy = -1

    step=i+1
    print("STARTING LwF TRAINING WITH GROUP:\t",step)  
    
    if step > 1:
      n_old_classes = CLASSES_PER_GROUP*(step-1)
      train_dataloader,val_dataloader,test_dataloader = utils.create_dataloaders(training_set,test_set,step,BATCH_SIZE)
      myNet.update_network(best_net,CLASSES_PER_GROUP + n_old_classes,myNet.init_weights)
      
    optimizer,scheduler = myNet.prepare_training(LR,MOMENTUM,WEIGHT_DECAY,STEP_SIZE,GAMMA,typeScheduler=typeScheduler)

    losses_train = []
    losses_val = []
    val_accuracies = []
    train_accuracies = []
    classification_losses = []
    distillation_losses = []

    myNet.net = myNet.net.to(DEVICE)
    cudnn.benchmark 

    for epoch in range(NUM_EPOCHS):
        running_correct_train = 0
        if typeScheduler == 'multistep':
          print('Starting epoch {}/{}, LR = {}'.format(epoch+1, NUM_EPOCHS, scheduler.get_last_lr()))
        elif typeScheduler == 'plateau':
          print('Starting epoch {}/{}, LR = {}'.format(epoch+1, NUM_EPOCHS, optimizer.param_groups[0]['lr']))

        myNet.net.train() # Set Network to train mode
        current_step = 0
        losses_tmp = []
        for images, labels, _ in train_dataloader:
            images = images.to(DEVICE)
            labels = labels.to(DEVICE)

            #Set all gradients to zero
            optimizer.zero_grad() 

            #Computing output and creating the acyclic graph for updating the gradients
            outputs = myNet.net(images)

            #Computing predictions
            _, preds = torch.max(outputs.data, 1)
            
            if(step > 1):
                old_outputs = myNet.get_old_outputs(images,labels)

            loss,clf_loss,dist_loss = myLoss.icarl_loss(old_outputs,outputs,labels,step,current_step,utils,CLASSES_PER_GROUP)
            classification_losses.append(clf_loss.item())
            distillation_losses.append(dist_loss.item())
            losses_tmp.append(loss.item())

            #Calculate correct predictions
            running_correct_train += torch.sum(preds == labels.data).data.item()

            #Accumulate gradients
            loss.backward()

            # Update weights based on accumulated gradients  
            optimizer.step() 

            current_step += 1

        #Calculate training accuracy
        train_accuracy = running_correct_train/len(train_dataloader.dataset)

        #Validate the model
        val_accuracy,val_loss = validation(val_dataloader,myNet.net,myLoss)

        print("Accuracy on the training :\t",train_accuracy)
        print("Accuracy on the validation :\t",val_accuracy)

        #Save the net which minimizes the accuracy on the validation
        if val_accuracy > best_val_accuracy:
            best_net = copy.deepcopy(myNet.net)
            best_train_accuracy = train_accuracy
            best_val_accuracy = val_accuracy
        
        train_accuracies.append(train_accuracy)
        val_accuracies.append(val_accuracy)
        losses_train.append(np.array(losses_tmp).mean())

        # Step the scheduler
        if typeScheduler == 'multistep':
            scheduler.step()
        #Reduce the learning rate when the validation loss reaches a plateau
        elif typeScheduler == 'plateau':
            scheduler.step(val_loss)

    # Save accuracies and losses            
    print("Best accuracy on the training :\t",best_train_accuracy)
    print("Best accuracy on the validation :\t",best_val_accuracy)
    losses_train_all.append(losses_train)
    best_train_accuracies.append(best_train_accuracy)
    best_val_accuracies.append(best_val_accuracy)

    #Test 
    test_accuracy,test_matrix = validation(test_dataloader,best_net,myLoss,conf_matrix=True)
    print("Accuracy on the test :\t",test_accuracy)
    best_test_accuracies.append(test_accuracy)
    
    utils.writeOnFileMetrics('LwFMetrics_icarlLoss_plateau.json', step, [best_train_accuracy,best_val_accuracy,test_accuracy,test_matrix.tolist()])
    utils.writeOnFileLosses('LwFLosses_icarlLoss_plateau.json', step, [classification_losses,distillation_losses])
    # !cp  './LwFMetrics_icarlLoss_plateau.json' './gdrive/My Drive/LwFMetrics_icarlLoss_plateau.json'
    # !cp  './LwFLosses_icarlLoss_plateau.json' './gdrive/My Drive/LwFLosses_icarlLoss_plateau.json'
# Out:
# STARTING LwF TRAINING WITH GROUP:	 1
# Starting epoch 1/70, LR = 2
# Accuracy on the training :	 0.11577777777777777
# Accuracy on the validation :	 0.132
# Starting epoch 2/70, LR = 2
# Accuracy on the training :	 0.14422222222222222
# Accuracy on the validation :	 0.138
# Starting epoch 3/70, LR = 2
# Accuracy on the training :	 0.15311111111111111
# Accuracy on the validation :	 0.166
# Starting epoch 4/70, LR = 2
# Accuracy on the training :	 0.18222222222222223
# Accuracy on the validation :	 0.21
# Starting epoch 5/70, LR = 2
# Accuracy on the training :	 0.206
# Accuracy on the validation :	 0.176
# Starting epoch 6/70, LR = 2
# Accuracy on the training :	 0.22777777777777777
# Accuracy on the validation :	 0.236
# Starting epoch 7/70, LR = 2
# Accuracy on the training :	 0.2348888888888889
# Accuracy on the validation :	 0.254
# Starting epoch 8/70, LR = 2
# Accuracy on the training :	 0.26066666666666666
# Accuracy on the validation :	 0.228
# Starting epoch 9/70, LR = 2
# Accuracy on the training :	 0.2737777777777778
# Accuracy on the validation :	 0.286
# Starting epoch 10/70, LR = 2
# Accuracy on the training :	 0.2693333333333333
# Accuracy on the validation :	 0.204
# Starting epoch 11/70, LR = 2
# Accuracy on the training :	 0.29288888888888887
# Accuracy on the validation :	 0.298
# Starting epoch 12/70, LR = 2
# Accuracy on the training :	 0.29888888888888887
# Accuracy on the validation :	 0.334
# Starting epoch 13/70, LR = 2
# Accuracy on the training :	 0.3171111111111111
# Accuracy on the validation :	 0.256
# Starting epoch 14/70, LR = 2
# Accuracy on the training :	 0.328
# Accuracy on the validation :	 0.342
# Starting epoch 15/70, LR = 2
# Accuracy on the training :	 0.3502222222222222
# Accuracy on the validation :	 0.302
# Starting epoch 16/70, LR = 2
# Accuracy on the training :	 0.39866666666666667
# Accuracy on the validation :	 0.412
# Starting epoch 17/70, LR = 2
# Accuracy on the training :	 0.4151111111111111
# Accuracy on the validation :	 0.442
# Starting epoch 18/70, LR = 2
# Accuracy on the training :	 0.45666666666666667
# Accuracy on the validation :	 0.436
# Starting epoch 19/70, LR = 2
# Accuracy on the training :	 0.4822222222222222
# Accuracy on the validation :	 0.366
# Starting epoch 20/70, LR = 2
# Accuracy on the training :	 0.5035555555555555
# Accuracy on the validation :	 0.468
# Starting epoch 21/70, LR = 2
# Accuracy on the training :	 0.5395555555555556
# Accuracy on the validation :	 0.46
# Starting epoch 22/70, LR = 2
# Accuracy on the training :	 0.5531111111111111
# Accuracy on the validation :	 0.488
# Starting epoch 23/70, LR = 2
# Accuracy on the training :	 0.5842222222222222
# Accuracy on the validation :	 0.528
# Starting epoch 24/70, LR = 2
# Accuracy on the training :	 0.6017777777777777
# Accuracy on the validation :	 0.576
# Starting epoch 25/70, LR = 2
# Accuracy on the training :	 0.6197777777777778
# Accuracy on the validation :	 0.538
# Starting epoch 26/70, LR = 2
# Accuracy on the training :	 0.6311111111111111
# Accuracy on the validation :	 0.528
# Starting epoch 27/70, LR = 2
# Accuracy on the training :	 0.6462222222222223
# Accuracy on the validation :	 0.63
# Starting epoch 28/70, LR = 2
# Accuracy on the training :	 0.6686666666666666
# Accuracy on the validation :	 0.518
# Starting epoch 29/70, LR = 2
# Accuracy on the training :	 0.6808888888888889
# Accuracy on the validation :	 0.634
# Starting epoch 30/70, LR = 2
# Accuracy on the training :	 0.7046666666666667
# Accuracy on the validation :	 0.636
# Starting epoch 31/70, LR = 2
# Accuracy on the training :	 0.7104444444444444
# Accuracy on the validation :	 0.668
# Starting epoch 32/70, LR = 2
# Accuracy on the training :	 0.7268888888888889
# Accuracy on the validation :	 0.674
# Starting epoch 33/70, LR = 2
# Accuracy on the training :	 0.7351111111111112
# Accuracy on the validation :	 0.606
# Starting epoch 34/70, LR = 2
# Accuracy on the training :	 0.7466666666666667
# Accuracy on the validation :	 0.652
# Starting epoch 35/70, LR = 2
# Accuracy on the training :	 0.7448888888888889
# Accuracy on the validation :	 0.68
# Starting epoch 36/70, LR = 2
# Accuracy on the training :	 0.7555555555555555
# Accuracy on the validation :	 0.714
# Starting epoch 37/70, LR = 2
# Accuracy on the training :	 0.7651111111111111
# Accuracy on the validation :	 0.712
# Starting epoch 38/70, LR = 2
# Accuracy on the training :	 0.7813333333333333
# Accuracy on the validation :	 0.748
# Starting epoch 39/70, LR = 2
# Accuracy on the training :	 0.7897777777777778
# Accuracy on the validation :	 0.732
# Starting epoch 40/70, LR = 2
# Accuracy on the training :	 0.8046666666666666
# Accuracy on the validation :	 0.712
# Starting epoch 41/70, LR = 2
# Accuracy on the training :	 0.8022222222222222
# Accuracy on the validation :	 0.706
# Starting epoch 42/70, LR = 2
# Accuracy on the training :	 0.8091111111111111
# Accuracy on the validation :	 0.774
# Starting epoch 43/70, LR = 2
# Accuracy on the training :	 0.8271111111111111
# Accuracy on the validation :	 0.696
# Starting epoch 44/70, LR = 2
# Accuracy on the training :	 0.816
# Accuracy on the validation :	 0.696
# Starting epoch 45/70, LR = 2
# Accuracy on the training :	 0.8311111111111111
# Accuracy on the validation :	 0.66
# Starting epoch 46/70, LR = 2
# Accuracy on the training :	 0.8351111111111111
# Accuracy on the validation :	 0.752
# Starting epoch 47/70, LR = 2
# Accuracy on the training :	 0.8415555555555555
# Accuracy on the validation :	 0.774
# Starting epoch 48/70, LR = 2
# Accuracy on the training :	 0.8322222222222222
# Accuracy on the validation :	 0.72
# Starting epoch 49/70, LR = 2
# Accuracy on the training :	 0.8426666666666667
# Accuracy on the validation :	 0.754
# Starting epoch 50/70, LR = 2
# Accuracy on the training :	 0.8671111111111112
# Accuracy on the validation :	 0.744
# Starting epoch 51/70, LR = 2
# Accuracy on the training :	 0.8733333333333333
# Accuracy on the validation :	 0.762
# Starting epoch 52/70, LR = 2
# Accuracy on the training :	 0.8602222222222222
# Accuracy on the validation :	 0.766
# Starting epoch 53/70, LR = 2
# Accuracy on the training :	 0.8671111111111112
# Accuracy on the validation :	 0.756
# Starting epoch 54/70, LR = 2
# Accuracy on the training :	 0.8737777777777778
# Accuracy on the validation :	 0.768
# Starting epoch 55/70, LR = 2
# Accuracy on the training :	 0.8724444444444445
# Accuracy on the validation :	 0.778
# Starting epoch 56/70, LR = 2
# Accuracy on the training :	 0.8657777777777778
# Accuracy on the validation :	 0.8
# Starting epoch 57/70, LR = 2
# Accuracy on the training :	 0.8746666666666667
# Accuracy on the validation :	 0.736
# Starting epoch 58/70, LR = 0.2
# Accuracy on the training :	 0.9051111111111111
# Accuracy on the validation :	 0.838
# Starting epoch 59/70, LR = 0.2
# Accuracy on the training :	 0.9286666666666666
# Accuracy on the validation :	 0.842
# Starting epoch 60/70, LR = 0.2
# Accuracy on the training :	 0.9377777777777778
# Accuracy on the validation :	 0.858
# Starting epoch 61/70, LR = 0.2
# Accuracy on the training :	 0.9411111111111111
# Accuracy on the validation :	 0.84
# Starting epoch 62/70, LR = 0.2
# Accuracy on the training :	 0.948
# Accuracy on the validation :	 0.848
# Starting epoch 63/70, LR = 0.2
# Accuracy on the training :	 0.9446666666666667
# Accuracy on the validation :	 0.864
# Starting epoch 64/70, LR = 0.2
# Accuracy on the training :	 0.9508888888888889
# Accuracy on the validation :	 0.842
# Starting epoch 65/70, LR = 0.2
# Accuracy on the training :	 0.9495555555555556
# Accuracy on the validation :	 0.854
# Starting epoch 66/70, LR = 0.2
# Accuracy on the training :	 0.9562222222222222
# Accuracy on the validation :	 0.846
# Starting epoch 67/70, LR = 0.2
# Accuracy on the training :	 0.9522222222222222
# Accuracy on the validation :	 0.85
# Starting epoch 68/70, LR = 0.2
# Accuracy on the training :	 0.958
# Accuracy on the validation :	 0.858
# Starting epoch 69/70, LR = 0.2
# Accuracy on the training :	 0.9644444444444444
# Accuracy on the validation :	 0.86
# Starting epoch 70/70, LR = 0.2
# Accuracy on the training :	 0.9606666666666667
# Accuracy on the validation :	 0.856
# Best accuracy on the training :	 0.9446666666666667
# Best accuracy on the validation :	 0.864
# Accuracy on the test :	 0.873
# STARTING LwF TRAINING WITH GROUP:	 2
# Starting epoch 1/70, LR = 2
# Accuracy on the training :	 0.092
# Accuracy on the validation :	 0.467
# Starting epoch 2/70, LR = 2
# Accuracy on the training :	 0.22955555555555557
# Accuracy on the validation :	 0.556
# Starting epoch 3/70, LR = 2
# Accuracy on the training :	 0.37222222222222223
# Accuracy on the validation :	 0.62
# Starting epoch 4/70, LR = 2
# Accuracy on the training :	 0.46066666666666667
# Accuracy on the validation :	 0.615
# Starting epoch 5/70, LR = 2
# Accuracy on the training :	 0.5304444444444445
# Accuracy on the validation :	 0.573
# Starting epoch 6/70, LR = 2
# Accuracy on the training :	 0.5495555555555556
# Accuracy on the validation :	 0.637
# Starting epoch 7/70, LR = 2
# Accuracy on the training :	 0.6022222222222222
# Accuracy on the validation :	 0.635
# Starting epoch 8/70, LR = 2
# Accuracy on the training :	 0.62
# Accuracy on the validation :	 0.641
# Starting epoch 9/70, LR = 2
# Accuracy on the training :	 0.6255555555555555
# Accuracy on the validation :	 0.646
# Starting epoch 10/70, LR = 2
# Accuracy on the training :	 0.6597777777777778
# Accuracy on the validation :	 0.643
# Starting epoch 11/70, LR = 2
# Accuracy on the training :	 0.6713333333333333
# Accuracy on the validation :	 0.676
# Starting epoch 12/70, LR = 2
# Accuracy on the training :	 0.6895555555555556
# Accuracy on the validation :	 0.637
# Starting epoch 13/70, LR = 2
# Accuracy on the training :	 0.6995555555555556
# Accuracy on the validation :	 0.634
# Starting epoch 14/70, LR = 2
# Accuracy on the training :	 0.7071111111111111
# Accuracy on the validation :	 0.647
# Starting epoch 15/70, LR = 2
# Accuracy on the training :	 0.7268888888888889
# Accuracy on the validation :	 0.636
# Starting epoch 16/70, LR = 2
# Accuracy on the training :	 0.7415555555555555
# Accuracy on the validation :	 0.644
# Starting epoch 17/70, LR = 2
# Accuracy on the training :	 0.7504444444444445
# Accuracy on the validation :	 0.597
# Starting epoch 18/70, LR = 2
# Accuracy on the training :	 0.7491111111111111
# Accuracy on the validation :	 0.673
# Starting epoch 19/70, LR = 2
# Accuracy on the training :	 0.7675555555555555
# Accuracy on the validation :	 0.683
# Starting epoch 20/70, LR = 2
# Accuracy on the training :	 0.7608888888888888
# Accuracy on the validation :	 0.652
# Starting epoch 21/70, LR = 2
# Accuracy on the training :	 0.7757777777777778
# Accuracy on the validation :	 0.664
# Starting epoch 22/70, LR = 2
# Accuracy on the training :	 0.7875555555555556
# Accuracy on the validation :	 0.649
# Starting epoch 23/70, LR = 0.2
# Accuracy on the training :	 0.8324444444444444
# Accuracy on the validation :	 0.727
# Starting epoch 24/70, LR = 0.2
# Accuracy on the training :	 0.8437777777777777
# Accuracy on the validation :	 0.704
# Starting epoch 25/70, LR = 0.2
# Accuracy on the training :	 0.8508888888888889
# Accuracy on the validation :	 0.733
# Starting epoch 26/70, LR = 0.2
# Accuracy on the training :	 0.8571111111111112
# Accuracy on the validation :	 0.718
# Starting epoch 27/70, LR = 0.2
# Accuracy on the training :	 0.8542222222222222
# Accuracy on the validation :	 0.723
# Starting epoch 28/70, LR = 0.2
# Accuracy on the training :	 0.8595555555555555
# Accuracy on the validation :	 0.726
# Starting epoch 29/70, LR = 0.2
# Accuracy on the training :	 0.8633333333333333
# Accuracy on the validation :	 0.727
# Starting epoch 30/70, LR = 0.2
# Accuracy on the training :	 0.8602222222222222
# Accuracy on the validation :	 0.714
# Starting epoch 31/70, LR = 0.2
# Accuracy on the training :	 0.8728888888888889
# Accuracy on the validation :	 0.728
# Starting epoch 32/70, LR = 0.2
# Accuracy on the training :	 0.868
# Accuracy on the validation :	 0.726
# Starting epoch 33/70, LR = 0.2
# Accuracy on the training :	 0.8746666666666667
# Accuracy on the validation :	 0.745
# Starting epoch 34/70, LR = 0.2
# Accuracy on the training :	 0.8746666666666667
# Accuracy on the validation :	 0.729
# Starting epoch 35/70, LR = 0.2
# Accuracy on the training :	 0.8726666666666667
# Accuracy on the validation :	 0.713
# Starting epoch 36/70, LR = 0.2
# Accuracy on the training :	 0.8844444444444445
# Accuracy on the validation :	 0.708
# Starting epoch 37/70, LR = 0.2
# Accuracy on the training :	 0.8773333333333333
# Accuracy on the validation :	 0.733
# Starting epoch 38/70, LR = 0.2
# Accuracy on the training :	 0.8904444444444445
# Accuracy on the validation :	 0.708
# Starting epoch 39/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.882
# Accuracy on the validation :	 0.715
# Starting epoch 40/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8902222222222222
# Accuracy on the validation :	 0.707
# Starting epoch 41/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8888888888888888
# Accuracy on the validation :	 0.727
# Starting epoch 42/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8873333333333333
# Accuracy on the validation :	 0.723
# Starting epoch 43/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8857777777777778
# Accuracy on the validation :	 0.721
# Starting epoch 44/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8911111111111111
# Accuracy on the validation :	 0.715
# Starting epoch 45/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8942222222222223
# Accuracy on the validation :	 0.723
# Starting epoch 46/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8948888888888888
# Accuracy on the validation :	 0.713
# Starting epoch 47/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.9022222222222223
# Accuracy on the validation :	 0.717
# Starting epoch 48/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8975555555555556
# Accuracy on the validation :	 0.718
# Starting epoch 49/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8933333333333333
# Accuracy on the validation :	 0.726
# Starting epoch 50/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8957777777777778
# Accuracy on the validation :	 0.728
# Starting epoch 51/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8884444444444445
# Accuracy on the validation :	 0.731
# Starting epoch 52/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.892
# Accuracy on the validation :	 0.719
# Starting epoch 53/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8911111111111111
# Accuracy on the validation :	 0.718
# Starting epoch 54/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8942222222222223
# Accuracy on the validation :	 0.733
# Starting epoch 55/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8911111111111111
# Accuracy on the validation :	 0.71
# Starting epoch 56/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8955555555555555
# Accuracy on the validation :	 0.736
# Starting epoch 57/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8906666666666667
# Accuracy on the validation :	 0.73
# Starting epoch 58/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8997777777777778
# Accuracy on the validation :	 0.723
# Starting epoch 59/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8984444444444445
# Accuracy on the validation :	 0.741
# Starting epoch 60/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.892
# Accuracy on the validation :	 0.732
# Starting epoch 61/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.8928888888888888
# Accuracy on the validation :	 0.737
# Starting epoch 62/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.8911111111111111
# Accuracy on the validation :	 0.733
# Starting epoch 63/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.892
# Accuracy on the validation :	 0.73
# Starting epoch 64/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.8911111111111111
# Accuracy on the validation :	 0.731
# Starting epoch 65/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.8962222222222223
# Accuracy on the validation :	 0.727
# Starting epoch 66/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.9013333333333333
# Accuracy on the validation :	 0.713
# Starting epoch 67/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.8915555555555555
# Accuracy on the validation :	 0.728
# Starting epoch 68/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.8971111111111111
# Accuracy on the validation :	 0.726
# Starting epoch 69/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.8935555555555555
# Accuracy on the validation :	 0.731
# Starting epoch 70/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.8908888888888888
# Accuracy on the validation :	 0.723
# Best accuracy on the training :	 0.8746666666666667
# Best accuracy on the validation :	 0.745
# Accuracy on the test :	 0.7105
# STARTING LwF TRAINING WITH GROUP:	 3
# Starting epoch 1/70, LR = 2
# Accuracy on the training :	 0.07777777777777778
# Accuracy on the validation :	 0.4686666666666667
# Starting epoch 2/70, LR = 2
# Accuracy on the training :	 0.228
# Accuracy on the validation :	 0.5033333333333333
# Starting epoch 3/70, LR = 2
# Accuracy on the training :	 0.29577777777777775
# Accuracy on the validation :	 0.522
# Starting epoch 4/70, LR = 2
# Accuracy on the training :	 0.3477777777777778
# Accuracy on the validation :	 0.5306666666666666
# Starting epoch 5/70, LR = 2
# Accuracy on the training :	 0.38666666666666666
# Accuracy on the validation :	 0.524
# Starting epoch 6/70, LR = 2
# Accuracy on the training :	 0.412
# Accuracy on the validation :	 0.512
# Starting epoch 7/70, LR = 2
# Accuracy on the training :	 0.436
# Accuracy on the validation :	 0.49666666666666665
# Starting epoch 8/70, LR = 2
# Accuracy on the training :	 0.47244444444444444
# Accuracy on the validation :	 0.5053333333333333
# Starting epoch 9/70, LR = 2
# Accuracy on the training :	 0.4971111111111111
# Accuracy on the validation :	 0.48933333333333334
# Starting epoch 10/70, LR = 2
# Accuracy on the training :	 0.5182222222222223
# Accuracy on the validation :	 0.496
# Starting epoch 11/70, LR = 2
# Accuracy on the training :	 0.5342222222222223
# Accuracy on the validation :	 0.496
# Starting epoch 12/70, LR = 2
# Accuracy on the training :	 0.5533333333333333
# Accuracy on the validation :	 0.5006666666666667
# Starting epoch 13/70, LR = 2
# Accuracy on the training :	 0.5811111111111111
# Accuracy on the validation :	 0.5153333333333333
# Starting epoch 14/70, LR = 2
# Accuracy on the training :	 0.6011111111111112
# Accuracy on the validation :	 0.518
# Starting epoch 15/70, LR = 2
# Accuracy on the training :	 0.6086666666666667
# Accuracy on the validation :	 0.494
# Starting epoch 16/70, LR = 0.2
# Accuracy on the training :	 0.6557777777777778
# Accuracy on the validation :	 0.5406666666666666
# Starting epoch 17/70, LR = 0.2
# Accuracy on the training :	 0.6677777777777778
# Accuracy on the validation :	 0.546
# Starting epoch 18/70, LR = 0.2
# Accuracy on the training :	 0.6697777777777778
# Accuracy on the validation :	 0.544
# Starting epoch 19/70, LR = 0.2
# Accuracy on the training :	 0.6753333333333333
# Accuracy on the validation :	 0.5526666666666666
# Starting epoch 20/70, LR = 0.2
# Accuracy on the training :	 0.6775555555555556
# Accuracy on the validation :	 0.556
# Starting epoch 21/70, LR = 0.2
# Accuracy on the training :	 0.6775555555555556
# Accuracy on the validation :	 0.5533333333333333
# Starting epoch 22/70, LR = 0.2
# Accuracy on the training :	 0.6724444444444444
# Accuracy on the validation :	 0.5553333333333333
# Starting epoch 23/70, LR = 0.2
# Accuracy on the training :	 0.6851111111111111
# Accuracy on the validation :	 0.544
# Starting epoch 24/70, LR = 0.2
# Accuracy on the training :	 0.68
# Accuracy on the validation :	 0.5413333333333333
# Starting epoch 25/70, LR = 0.2
# Accuracy on the training :	 0.6908888888888889
# Accuracy on the validation :	 0.5366666666666666
# Starting epoch 26/70, LR = 0.2
# Accuracy on the training :	 0.7004444444444444
# Accuracy on the validation :	 0.5326666666666666
# Starting epoch 27/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.7004444444444444
# Accuracy on the validation :	 0.5406666666666666
# Starting epoch 28/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.7084444444444444
# Accuracy on the validation :	 0.5466666666666666
# Starting epoch 29/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.6997777777777778
# Accuracy on the validation :	 0.5453333333333333
# Starting epoch 30/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.7035555555555556
# Accuracy on the validation :	 0.5486666666666666
# Starting epoch 31/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.7022222222222222
# Accuracy on the validation :	 0.5393333333333333
# Starting epoch 32/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.6908888888888889
# Accuracy on the validation :	 0.542
# Starting epoch 33/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.6911111111111111
# Accuracy on the validation :	 0.552
# Starting epoch 34/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.704
# Accuracy on the validation :	 0.542
# Starting epoch 35/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.7015555555555556
# Accuracy on the validation :	 0.5453333333333333
# Starting epoch 36/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.7075555555555556
# Accuracy on the validation :	 0.5506666666666666
# Starting epoch 37/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.7011111111111111
# Accuracy on the validation :	 0.558
# Starting epoch 38/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.6995555555555556
# Accuracy on the validation :	 0.552
# Starting epoch 39/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.698
# Accuracy on the validation :	 0.5506666666666666
# Starting epoch 40/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.7044444444444444
# Accuracy on the validation :	 0.5493333333333333
# Starting epoch 41/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.7037777777777777
# Accuracy on the validation :	 0.5473333333333333
# Starting epoch 42/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.7124444444444444
# Accuracy on the validation :	 0.56
# Starting epoch 43/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.7044444444444444
# Accuracy on the validation :	 0.5513333333333333
# Starting epoch 44/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.7008888888888889
# Accuracy on the validation :	 0.55
# Starting epoch 45/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.7051111111111111
# Accuracy on the validation :	 0.5413333333333333
# Starting epoch 46/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.7062222222222222
# Accuracy on the validation :	 0.5306666666666666
# Starting epoch 47/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.708
# Accuracy on the validation :	 0.5546666666666666
# Starting epoch 48/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.7051111111111111
# Accuracy on the validation :	 0.556
# Starting epoch 49/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.6966666666666667
# Accuracy on the validation :	 0.5486666666666666
# Starting epoch 50/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.7035555555555556
# Accuracy on the validation :	 0.5466666666666666
# Starting epoch 51/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.702
# Accuracy on the validation :	 0.5573333333333333
# Starting epoch 52/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.7062222222222222
# Accuracy on the validation :	 0.5466666666666666
# Starting epoch 53/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.7
# Accuracy on the validation :	 0.5466666666666666
# Starting epoch 54/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.7004444444444444
# Accuracy on the validation :	 0.542
# Starting epoch 55/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.7002222222222222
# Accuracy on the validation :	 0.5406666666666666
# Starting epoch 56/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.6968888888888889
# Accuracy on the validation :	 0.5466666666666666
# Starting epoch 57/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.7044444444444444
# Accuracy on the validation :	 0.5433333333333333
# Starting epoch 58/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.7002222222222222
# Accuracy on the validation :	 0.5326666666666666
# Starting epoch 59/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.7022222222222222
# Accuracy on the validation :	 0.5473333333333333
# Starting epoch 60/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.7086666666666667
# Accuracy on the validation :	 0.5513333333333333
# Starting epoch 61/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.7075555555555556
# Accuracy on the validation :	 0.5526666666666666
# Starting epoch 62/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.7042222222222222
# Accuracy on the validation :	 0.5433333333333333
# Starting epoch 63/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.7097777777777777
# Accuracy on the validation :	 0.548
# Starting epoch 64/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.7075555555555556
# Accuracy on the validation :	 0.5326666666666666
# Starting epoch 65/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.7111111111111111
# Accuracy on the validation :	 0.5566666666666666
# Starting epoch 66/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.7017777777777777
# Accuracy on the validation :	 0.5373333333333333
# Starting epoch 67/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.7044444444444444
# Accuracy on the validation :	 0.5526666666666666
# Starting epoch 68/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.708
# Accuracy on the validation :	 0.5426666666666666
# Starting epoch 69/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.704
# Accuracy on the validation :	 0.552
# Starting epoch 70/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.708
# Accuracy on the validation :	 0.5493333333333333
# Best accuracy on the training :	 0.7124444444444444
# Best accuracy on the validation :	 0.56
# Accuracy on the test :	 0.5313333333333333
# STARTING LwF TRAINING WITH GROUP:	 4
# Starting epoch 1/70, LR = 2
# Accuracy on the training :	 0.03755555555555556
# Accuracy on the validation :	 0.4045
# Starting epoch 2/70, LR = 2
# Accuracy on the training :	 0.118
# Accuracy on the validation :	 0.421
# Starting epoch 3/70, LR = 2
# Accuracy on the training :	 0.17866666666666667
# Accuracy on the validation :	 0.453
# Starting epoch 4/70, LR = 2
# Accuracy on the training :	 0.23133333333333334
# Accuracy on the validation :	 0.453
# Starting epoch 5/70, LR = 2
# Accuracy on the training :	 0.2657777777777778
# Accuracy on the validation :	 0.457
# Starting epoch 6/70, LR = 2
# Accuracy on the training :	 0.30622222222222223
# Accuracy on the validation :	 0.443
# Starting epoch 7/70, LR = 2
# Accuracy on the training :	 0.35444444444444445
# Accuracy on the validation :	 0.4395
# Starting epoch 8/70, LR = 2
# Accuracy on the training :	 0.36977777777777776
# Accuracy on the validation :	 0.4485
# Starting epoch 9/70, LR = 2
# Accuracy on the training :	 0.39866666666666667
# Accuracy on the validation :	 0.429
# Starting epoch 10/70, LR = 2
# Accuracy on the training :	 0.42444444444444446
# Accuracy on the validation :	 0.4345
# Starting epoch 11/70, LR = 2
# Accuracy on the training :	 0.4424444444444444
# Accuracy on the validation :	 0.4655
# Starting epoch 12/70, LR = 2
# Accuracy on the training :	 0.4633333333333333
# Accuracy on the validation :	 0.4345
# Starting epoch 13/70, LR = 2
# Accuracy on the training :	 0.4855555555555556
# Accuracy on the validation :	 0.434
# Starting epoch 14/70, LR = 2
# Accuracy on the training :	 0.5055555555555555
# Accuracy on the validation :	 0.445
# Starting epoch 15/70, LR = 2
# Accuracy on the training :	 0.5246666666666666
# Accuracy on the validation :	 0.428
# Starting epoch 16/70, LR = 0.2
# Accuracy on the training :	 0.5413333333333333
# Accuracy on the validation :	 0.4725
# Starting epoch 17/70, LR = 0.2
# Accuracy on the training :	 0.556
# Accuracy on the validation :	 0.467
# Starting epoch 18/70, LR = 0.2
# Accuracy on the training :	 0.5642222222222222
# Accuracy on the validation :	 0.471
# Starting epoch 19/70, LR = 0.2
# Accuracy on the training :	 0.5582222222222222
# Accuracy on the validation :	 0.469
# Starting epoch 20/70, LR = 0.2
# Accuracy on the training :	 0.5684444444444444
# Accuracy on the validation :	 0.4635
# Starting epoch 21/70, LR = 0.2
# Accuracy on the training :	 0.5711111111111111
# Accuracy on the validation :	 0.461
# Starting epoch 22/70, LR = 0.2
# Accuracy on the training :	 0.5813333333333334
# Accuracy on the validation :	 0.4785
# Starting epoch 23/70, LR = 0.2
# Accuracy on the training :	 0.5757777777777778
# Accuracy on the validation :	 0.4785
# Starting epoch 24/70, LR = 0.2
# Accuracy on the training :	 0.5888888888888889
# Accuracy on the validation :	 0.4705
# Starting epoch 25/70, LR = 0.2
# Accuracy on the training :	 0.5922222222222222
# Accuracy on the validation :	 0.461
# Starting epoch 26/70, LR = 0.2
# Accuracy on the training :	 0.5875555555555556
# Accuracy on the validation :	 0.4745
# Starting epoch 27/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.6006666666666667
# Accuracy on the validation :	 0.487
# Starting epoch 28/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.5893333333333334
# Accuracy on the validation :	 0.4725
# Starting epoch 29/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.6008888888888889
# Accuracy on the validation :	 0.4715
# Starting epoch 30/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.5926666666666667
# Accuracy on the validation :	 0.4805
# Starting epoch 31/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.5991111111111111
# Accuracy on the validation :	 0.4745
# Starting epoch 32/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.598
# Accuracy on the validation :	 0.4775
# Starting epoch 33/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.5973333333333334
# Accuracy on the validation :	 0.4695
# Starting epoch 34/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.5855555555555556
# Accuracy on the validation :	 0.47
# Starting epoch 35/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.6035555555555555
# Accuracy on the validation :	 0.4875
# Starting epoch 36/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.6115555555555555
# Accuracy on the validation :	 0.476
# Starting epoch 37/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.6002222222222222
# Accuracy on the validation :	 0.4805
# Starting epoch 38/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.5962222222222222
# Accuracy on the validation :	 0.48
# Starting epoch 39/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.5971111111111111
# Accuracy on the validation :	 0.475
# Starting epoch 40/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.5928888888888889
# Accuracy on the validation :	 0.4805
# Starting epoch 41/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.5944444444444444
# Accuracy on the validation :	 0.478
# Starting epoch 42/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.6028888888888889
# Accuracy on the validation :	 0.4745
# Starting epoch 43/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.5977777777777777
# Accuracy on the validation :	 0.481
# Starting epoch 44/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.5911111111111111
# Accuracy on the validation :	 0.4745
# Starting epoch 45/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.598
# Accuracy on the validation :	 0.4755
# Starting epoch 46/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.5933333333333334
# Accuracy on the validation :	 0.4575
# Starting epoch 47/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.6006666666666667
# Accuracy on the validation :	 0.469
# Starting epoch 48/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.5911111111111111
# Accuracy on the validation :	 0.4835
# Starting epoch 49/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.6044444444444445
# Accuracy on the validation :	 0.4755
# Starting epoch 50/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.6046666666666667
# Accuracy on the validation :	 0.464
# Starting epoch 51/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.5935555555555555
# Accuracy on the validation :	 0.4785
# Starting epoch 52/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.5988888888888889
# Accuracy on the validation :	 0.468
# Starting epoch 53/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.5951111111111111
# Accuracy on the validation :	 0.478
# Starting epoch 54/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.5986666666666667
# Accuracy on the validation :	 0.4755
# Starting epoch 55/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.6006666666666667
# Accuracy on the validation :	 0.469
# Starting epoch 56/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.6024444444444444
# Accuracy on the validation :	 0.471
# Starting epoch 57/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.5997777777777777
# Accuracy on the validation :	 0.479
# Starting epoch 58/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.5911111111111111
# Accuracy on the validation :	 0.4755
# Starting epoch 59/70, LR = 0.00020000000000000006
# Accuracy on the training :	 0.5968888888888889
# Accuracy on the validation :	 0.4685
# Starting epoch 60/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.5886666666666667
# Accuracy on the validation :	 0.468
# Starting epoch 61/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.596
# Accuracy on the validation :	 0.478
# Starting epoch 62/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.6
# Accuracy on the validation :	 0.472
# Starting epoch 63/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.602
# Accuracy on the validation :	 0.4725
# Starting epoch 64/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.5997777777777777
# Accuracy on the validation :	 0.482
# Starting epoch 65/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.5913333333333334
# Accuracy on the validation :	 0.4785
# Starting epoch 66/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.5962222222222222
# Accuracy on the validation :	 0.4755
# Starting epoch 67/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.6004444444444444
# Accuracy on the validation :	 0.4805
# Starting epoch 68/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.5924444444444444
# Accuracy on the validation :	 0.4675
# Starting epoch 69/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.5964444444444444
# Accuracy on the validation :	 0.4655
# Starting epoch 70/70, LR = 2.000000000000001e-05
# Accuracy on the training :	 0.5993333333333334
# Accuracy on the validation :	 0.4855
# Best accuracy on the training :	 0.6035555555555555
# Best accuracy on the validation :	 0.4875
# Accuracy on the test :	 0.4375
# STARTING LwF TRAINING WITH GROUP:	 5
# Starting epoch 1/70, LR = 2
# Accuracy on the training :	 0.04577777777777778
# Accuracy on the validation :	 0.3596
# Starting epoch 2/70, LR = 2
# Accuracy on the training :	 0.11711111111111111
# Accuracy on the validation :	 0.392
# Starting epoch 3/70, LR = 2
# Accuracy on the training :	 0.178
# Accuracy on the validation :	 0.3736
# Starting epoch 4/70, LR = 2
# Accuracy on the training :	 0.23066666666666666
# Accuracy on the validation :	 0.384
# Starting epoch 5/70, LR = 2
# Accuracy on the training :	 0.2906666666666667
# Accuracy on the validation :	 0.3896
# Starting epoch 6/70, LR = 2
# Accuracy on the training :	 0.33355555555555555
# Accuracy on the validation :	 0.3852
# Starting epoch 7/70, LR = 2
# Accuracy on the training :	 0.3768888888888889
# Accuracy on the validation :	 0.4008
# Starting epoch 8/70, LR = 2
# Accuracy on the training :	 0.4251111111111111
# Accuracy on the validation :	 0.3924
# Starting epoch 9/70, LR = 2
# Accuracy on the training :	 0.45511111111111113
# Accuracy on the validation :	 0.3976
# Starting epoch 10/70, LR = 2
# Accuracy on the training :	 0.4968888888888889
# Accuracy on the validation :	 0.394
# Starting epoch 11/70, LR = 2
# Accuracy on the training :	 0.5186666666666667
# Accuracy on the validation :	 0.3836
# Starting epoch 12/70, LR = 2
# Accuracy on the training :	 0.5506666666666666
# Accuracy on the validation :	 0.392
# Starting epoch 13/70, LR = 2
# Accuracy on the training :	 0.5833333333333334
# Accuracy on the validation :	 0.3952
# Starting epoch 14/70, LR = 2
# Accuracy on the training :	 0.6011111111111112
# Accuracy on the validation :	 0.3936
# Starting epoch 15/70, LR = 2
# Accuracy on the training :	 0.6186666666666667
# Accuracy on the validation :	 0.386
# Starting epoch 16/70, LR = 2
# Accuracy on the training :	 0.6373333333333333
# Accuracy on the validation :	 0.3788
# Starting epoch 17/70, LR = 2
# Accuracy on the training :	 0.6571111111111111
# Accuracy on the validation :	 0.3748
# Starting epoch 18/70, LR = 2
# Accuracy on the training :	 0.6837777777777778
# Accuracy on the validation :	 0.3968
# Starting epoch 19/70, LR = 2
# Accuracy on the training :	 0.692
# Accuracy on the validation :	 0.3656
# Starting epoch 20/70, LR = 2
# Accuracy on the training :	 0.6975555555555556
# Accuracy on the validation :	 0.3808
# Starting epoch 21/70, LR = 2
# Accuracy on the training :	 0.72
# Accuracy on the validation :	 0.388
# Starting epoch 22/70, LR = 2
# Accuracy on the training :	 0.7364444444444445
# Accuracy on the validation :	 0.378
# Starting epoch 23/70, LR = 2
# Accuracy on the training :	 0.7446666666666667
# Accuracy on the validation :	 0.3772
# Starting epoch 24/70, LR = 0.2
# Accuracy on the training :	 0.776
# Accuracy on the validation :	 0.4168
# Starting epoch 25/70, LR = 0.2
# Accuracy on the training :	 0.7933333333333333
# Accuracy on the validation :	 0.408
# Starting epoch 26/70, LR = 0.2
# Accuracy on the training :	 0.792
# Accuracy on the validation :	 0.404
# Starting epoch 27/70, LR = 0.2
# Accuracy on the training :	 0.8002222222222222
# Accuracy on the validation :	 0.408
# Starting epoch 28/70, LR = 0.2
# Accuracy on the training :	 0.7922222222222223
# Accuracy on the validation :	 0.4008
# Starting epoch 29/70, LR = 0.2
# Accuracy on the training :	 0.8135555555555556
# Accuracy on the validation :	 0.4052
# Starting epoch 30/70, LR = 0.2
# Accuracy on the training :	 0.8017777777777778
# Accuracy on the validation :	 0.4036
# Starting epoch 31/70, LR = 0.2
# Accuracy on the training :	 0.8164444444444444
# Accuracy on the validation :	 0.4044
# Starting epoch 32/70, LR = 0.2
# Accuracy on the training :	 0.8135555555555556
# Accuracy on the validation :	 0.4136
# Starting epoch 33/70, LR = 0.2
# Accuracy on the training :	 0.8191111111111111
# Accuracy on the validation :	 0.4136
# Starting epoch 34/70, LR = 0.2
# Accuracy on the training :	 0.8233333333333334
# Accuracy on the validation :	 0.4016
# Starting epoch 35/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8242222222222222
# Accuracy on the validation :	 0.4076
# Starting epoch 36/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8204444444444444
# Accuracy on the validation :	 0.4056
# Starting epoch 37/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8228888888888889
# Accuracy on the validation :	 0.4072
# Starting epoch 38/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8275555555555556
# Accuracy on the validation :	 0.4152
# Starting epoch 39/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.824
# Accuracy on the validation :	 0.4112
# Starting epoch 40/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8273333333333334
# Accuracy on the validation :	 0.4104
# Starting epoch 41/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8197777777777778
# Accuracy on the validation :	 0.4124
# Starting epoch 42/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8262222222222222
# Accuracy on the validation :	 0.4072
# Starting epoch 43/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8262222222222222
# Accuracy on the validation :	 0.4092
# Starting epoch 44/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8188888888888889
# Accuracy on the validation :	 0.412
# Starting epoch 45/70, LR = 0.020000000000000004
# Accuracy on the training :	 0.8248888888888889
# Accuracy on the validation :	 0.4092
# Starting epoch 46/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8335555555555556
# Accuracy on the validation :	 0.4112
# Starting epoch 47/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8275555555555556
# Accuracy on the validation :	 0.4136
# Starting epoch 48/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8211111111111111
# Accuracy on the validation :	 0.4176
# Starting epoch 49/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8295555555555556
# Accuracy on the validation :	 0.4028
# Starting epoch 50/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8266666666666667
# Accuracy on the validation :	 0.404
# Starting epoch 51/70, LR = 0.0020000000000000005
# Accuracy on the training :	 0.8273333333333334
# Accuracy on the validation :	 0.4036
# Starting epoch 52/70, LR = 0.0020000000000000005
