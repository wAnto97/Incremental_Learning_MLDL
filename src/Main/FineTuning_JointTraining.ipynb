# %%
# !rm -r 'IncrementalLeraningMLDL'
# !git clone "https://github.com/wAnto97/IncrementalLeraningMLDL"
from IncrementalLeraningMLDL.src.CIFAR100_dataset import MyCIFAR100
from IncrementalLeraningMLDL.src.Utils import Utils
from IncrementalLeraningMLDL.src.MyNet import MyNet
from IncrementalLeraningMLDL.src.Loss import Loss

import numpy as np
import sys
import copy
from torch.backends import cudnn
from torchvision import transforms
import torch
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from torch.utils.data import  DataLoader

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Cloning into 'IncrementalLeraningMLDL'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (47/47), done.
# remote: Total 942 (delta 33), reused 20 (delta 9), pack-reused 886
# Receiving objects: 100% (942/942), 10.62 MiB | 6.46 MiB/s, done.
# Resolving deltas: 100% (616/616), done.
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# **Loading data**

# %%
# Define transforms for training phase
train_transform = transforms.Compose([
                                      transforms.RandomCrop(32, padding=4),
                                      transforms.RandomHorizontalFlip(),
                                      transforms.ToTensor(), # Turn PIL Image to torch.Tensor
                                      transforms.Normalize( (0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))]) # Normalizes tensor with mean and standard deviation

# Define transforms for the evaluation phase
eval_transform = transforms.Compose([
                                      transforms.ToTensor(),
                                      transforms.Normalize( (0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010))])

training_set = MyCIFAR100('/content',train=True, n_groups=10, transform=train_transform, download=True)
test_set = MyCIFAR100('/content',train=False, n_groups=10, transform=eval_transform, download=True)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# **Hyperparameters**

# %%
DEVICE = 'cuda' # 'cuda' or 'cpu'  

BATCH_SIZE = 128      # Higher batch sizes allows for larger learning rates. An empirical heuristic suggests that, when changing
                     # the batch strain_dataloaderize, learning rate should change by the same factor to have comparable results
LR = 0.1            # The initial Learning Rate
MOMENTUM = 0.9       # Hyperparameter for SGD, keep this at 0.9 when using SGD
WEIGHT_DECAY = 1e-4  # Regularization, you can keep this at the default

NUM_EPOCHS = 70             # Total number of training epochs (iterations over dataset)
STEP_SIZE = [30,45,60]      # How many epochs before decreasing learning rate (if using a step-down policy)
GAMMA = 0.1                 # Multiplicative factor for learning rate step-down

LOG_FREQUENCY = 10

CLASSES_PER_GROUP = 10
NUM_GROUPS=10

# %% [markdown]
# **Utils functions**

# %%
###################################################################################################
#  If joint == True loads all groups until 'group', otherwise it allocates just the group 'group' #
###################################################################################################

def create_dataloaders(training_set,test_set,group,BATCH_SIZE,type):
    if(type == 'joint'):
        train,val = training_set.get_train_val_joint(group)
        test = test_set.get_groups_joint(group)
    if(type == 'finetuning'):
        train,val = training_set.get_single_train_joint_validation(group)
        test = test_set.get_groups_joint(group)
        
    train_dataloader =  DataLoader(train,batch_size=BATCH_SIZE,drop_last=True,num_workers=4,shuffle=True)
    val_dataloader = DataLoader(val,batch_size=BATCH_SIZE,drop_last=False,num_workers=4)
    test_dataloader = DataLoader(test,batch_size=BATCH_SIZE,drop_last=False,num_workers=4)

    return train_dataloader,val_dataloader,test_dataloader

# %%
def validation(val_dataloader,net,conf_matrix=False):
    net.train(False)
    running_corrects = 0
    y_pred = []
    all_labels = []
    for images, labels,_ in val_dataloader:

        images = images.to(DEVICE)
        labels = labels.to(DEVICE)

        # Forward Pass
        outputs = net(images)
        # Get predictions
        _, preds = torch.max(outputs.data, 1)
        # Update Corrects

        running_corrects += torch.sum(preds == labels.data).data.item()
        y_pred += list(map(lambda x : x.item(),preds))
        all_labels += list(labels)

        # Calculate Accuracy
    accuracy = running_corrects / float(len(val_dataloader.dataset))

    if(conf_matrix == True):
        all_labels = list(map(lambda label : label.item(),all_labels))
        return accuracy,confusion_matrix(y_pred,np.array(all_labels))

    return accuracy

# %% [markdown]
# **Main**

# %%
myNet = MyNet(n_classes=CLASSES_PER_GROUP)
utils = Utils()
myLoss = Loss()
typeScheduler='multistep' # In this case it can be only set to multistep
type_model = 'finetuning'

criterion = torch.nn.CrossEntropyLoss()
train_dataloader,val_dataloader,test_dataloader = create_dataloaders(training_set,test_set,1,BATCH_SIZE,type=type_model)

for i in range(NUM_GROUPS):
    best_val_accuracy = -1
    step=i+1
    print("STARTING FineTuning WITH GROUP:\t",step)  
    n_old_classes = CLASSES_PER_GROUP*(step-1)

    if step > 1:
        myNet.update_network(best_net,CLASSES_PER_GROUP + n_old_classes,myNet.init_weights)
        train_dataloader,val_dataloader,test_dataloader = create_dataloaders(training_set,test_set,step,BATCH_SIZE,type=type_model)

    optimizer,scheduler = myNet.prepare_training(LR,MOMENTUM,WEIGHT_DECAY,STEP_SIZE,GAMMA,typeScheduler=typeScheduler)

    current_step = 0
    myNet.net = myNet.net.to(DEVICE)
    cudnn.benchmark 

    # Start iterating over the epochs
    for epoch in range(NUM_EPOCHS):
        running_correct_train = 0
        print('Starting epoch {}/{}, LR = {}'.format(epoch+1, NUM_EPOCHS, scheduler.get_last_lr()))

        # Iterate over the dataset
        myNet.net.train() # Set Network to train mode
        for images, labels,_ in train_dataloader:            
            images = images.to(DEVICE)
            labels = labels.to(DEVICE)

            optimizer.zero_grad() # Zero-ing the gradients

            # Forward pass to the network
            outputs = myNet.net(images)
            _, preds = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)

            running_correct_train += torch.sum(preds == labels.data).data.item()

            loss.backward()  # backward pass: computes gradients
            if step>1 and type_model == 'finetuning':
              myNet.freeze_neurons(n_old_classes)
            optimizer.step() # update weights based on accumulated gradients
            current_step += 1

        train_accuracy = running_correct_train/len(train_dataloader.dataset)
        myNet.net.train(False)
        val_accuracy = validation(val_dataloader,myNet.net)

        print("Accuracy on the training :\t",train_accuracy)
        print("Accuracy on the validation :\t",val_accuracy)

        
        if val_accuracy > best_val_accuracy:
            best_net = copy.deepcopy(myNet.net)
            best_train_accuracy = train_accuracy
            best_val_accuracy = val_accuracy

        # Step the scheduler
        scheduler.step() 

    #Test on the train,val e test set
    test_accuracy,test_matrix = validation(test_dataloader,best_net,conf_matrix=True)
    print("Accuracy on the test :\t",test_accuracy)
    
    utils.writeOnFileMetrics('finetuningMetrics.json', step,[best_train_accuracy,best_val_accuracy,test_accuracy,test_matrix.tolist()])
    utils.writeOnFileLosses('finetuningLosses.json',step,[[],[]])
    # !cp  './finetuningLosses.json' './gdrive/My Drive/finetuningLosses.json'
    # !cp  './finetuningMetrics.json' './gdrive/My Drive/finetuningMetrics.json'
# Out:
# STARTING FineTuning WITH GROUP:	 1
# Starting epoch 1/70, LR = [0.1]
# Accuracy on the training :	 0.13244444444444445
# Accuracy on the validation :	 0.146
# Starting epoch 2/70, LR = [0.1]
# Accuracy on the training :	 0.20822222222222223
# Accuracy on the validation :	 0.274
# Starting epoch 3/70, LR = [0.1]
# Accuracy on the training :	 0.26711111111111113
# Accuracy on the validation :	 0.296
# Starting epoch 4/70, LR = [0.1]
# Accuracy on the training :	 0.3411111111111111
# Accuracy on the validation :	 0.256
# Starting epoch 5/70, LR = [0.1]
# Accuracy on the training :	 0.4053333333333333
# Accuracy on the validation :	 0.424
# Starting epoch 6/70, LR = [0.1]
# Accuracy on the training :	 0.4328888888888889
# Accuracy on the validation :	 0.424
# Starting epoch 7/70, LR = [0.1]
# Accuracy on the training :	 0.4693333333333333
# Accuracy on the validation :	 0.458
# Starting epoch 8/70, LR = [0.1]
# Accuracy on the training :	 0.5086666666666667
# Accuracy on the validation :	 0.484
# Starting epoch 9/70, LR = [0.1]
# Accuracy on the training :	 0.5555555555555556
# Accuracy on the validation :	 0.534
# Starting epoch 10/70, LR = [0.1]
# Accuracy on the training :	 0.5826666666666667
# Accuracy on the validation :	 0.508
# Starting epoch 11/70, LR = [0.1]
# Accuracy on the training :	 0.5982222222222222
# Accuracy on the validation :	 0.6
# Starting epoch 12/70, LR = [0.1]
# Accuracy on the training :	 0.6471111111111111
# Accuracy on the validation :	 0.594
# Starting epoch 13/70, LR = [0.1]
# Accuracy on the training :	 0.6673333333333333
# Accuracy on the validation :	 0.53
# Starting epoch 14/70, LR = [0.1]
# Accuracy on the training :	 0.688
# Accuracy on the validation :	 0.66
# Starting epoch 15/70, LR = [0.1]
# Accuracy on the training :	 0.6993333333333334
# Accuracy on the validation :	 0.644
# Starting epoch 16/70, LR = [0.1]
# Accuracy on the training :	 0.7266666666666667
# Accuracy on the validation :	 0.682
# Starting epoch 17/70, LR = [0.1]
# Accuracy on the training :	 0.7433333333333333
# Accuracy on the validation :	 0.532
# Starting epoch 18/70, LR = [0.1]
# Accuracy on the training :	 0.7511111111111111
# Accuracy on the validation :	 0.634
# Starting epoch 19/70, LR = [0.1]
# Accuracy on the training :	 0.7491111111111111
# Accuracy on the validation :	 0.69
# Starting epoch 20/70, LR = [0.1]
# Accuracy on the training :	 0.776
# Accuracy on the validation :	 0.722
# Starting epoch 21/70, LR = [0.1]
# Accuracy on the training :	 0.7913333333333333
# Accuracy on the validation :	 0.708
# Starting epoch 22/70, LR = [0.1]
# Accuracy on the training :	 0.7926666666666666
# Accuracy on the validation :	 0.752
# Starting epoch 23/70, LR = [0.1]
# Accuracy on the training :	 0.7924444444444444
# Accuracy on the validation :	 0.702
# Starting epoch 24/70, LR = [0.1]
# Accuracy on the training :	 0.8137777777777778
# Accuracy on the validation :	 0.73
# Starting epoch 25/70, LR = [0.1]
# Accuracy on the training :	 0.8062222222222222
# Accuracy on the validation :	 0.752
# Starting epoch 26/70, LR = [0.1]
# Accuracy on the training :	 0.8224444444444444
# Accuracy on the validation :	 0.764
# Starting epoch 27/70, LR = [0.1]
# Accuracy on the training :	 0.8284444444444444
# Accuracy on the validation :	 0.706
# Starting epoch 28/70, LR = [0.1]
# Accuracy on the training :	 0.8402222222222222
# Accuracy on the validation :	 0.77
# Starting epoch 29/70, LR = [0.1]
# Accuracy on the training :	 0.8451111111111111
# Accuracy on the validation :	 0.768
# Starting epoch 30/70, LR = [0.1]
# Accuracy on the training :	 0.8533333333333334
# Accuracy on the validation :	 0.758
# Starting epoch 31/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.8806666666666667
# Accuracy on the validation :	 0.846
# Starting epoch 32/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9042222222222223
# Accuracy on the validation :	 0.85
# Starting epoch 33/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9108888888888889
# Accuracy on the validation :	 0.844
# Starting epoch 34/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9113333333333333
# Accuracy on the validation :	 0.836
# Starting epoch 35/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9195555555555556
# Accuracy on the validation :	 0.844
# Starting epoch 36/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9257777777777778
# Accuracy on the validation :	 0.848
# Starting epoch 37/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9217777777777778
# Accuracy on the validation :	 0.834
# Starting epoch 38/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9191111111111111
# Accuracy on the validation :	 0.84
# Starting epoch 39/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9253333333333333
# Accuracy on the validation :	 0.844
# Starting epoch 40/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9297777777777778
# Accuracy on the validation :	 0.85
# Starting epoch 41/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9317777777777778
# Accuracy on the validation :	 0.826
# Starting epoch 42/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.93
# Accuracy on the validation :	 0.836
# Starting epoch 43/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9306666666666666
# Accuracy on the validation :	 0.842
# Starting epoch 44/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9373333333333334
# Accuracy on the validation :	 0.846
# Starting epoch 45/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.936
# Accuracy on the validation :	 0.812
# Starting epoch 46/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.94
# Accuracy on the validation :	 0.84
# Starting epoch 47/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9415555555555556
# Accuracy on the validation :	 0.854
# Starting epoch 48/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9406666666666667
# Accuracy on the validation :	 0.84
# Starting epoch 49/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9362222222222222
# Accuracy on the validation :	 0.828
# Starting epoch 50/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9371111111111111
# Accuracy on the validation :	 0.85
# Starting epoch 51/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9422222222222222
# Accuracy on the validation :	 0.84
# Starting epoch 52/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9504444444444444
# Accuracy on the validation :	 0.854
# Starting epoch 53/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9391111111111111
# Accuracy on the validation :	 0.83
# Starting epoch 54/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9397777777777778
# Accuracy on the validation :	 0.834
# Starting epoch 55/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9408888888888889
# Accuracy on the validation :	 0.854
# Starting epoch 56/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9468888888888889
# Accuracy on the validation :	 0.852
# Starting epoch 57/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9433333333333334
# Accuracy on the validation :	 0.852
# Starting epoch 58/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9448888888888889
# Accuracy on the validation :	 0.826
# Starting epoch 59/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9462222222222222
# Accuracy on the validation :	 0.84
# Starting epoch 60/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9444444444444444
# Accuracy on the validation :	 0.85
# Starting epoch 61/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9453333333333334
# Accuracy on the validation :	 0.862
# Starting epoch 62/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9402222222222222
# Accuracy on the validation :	 0.862
# Starting epoch 63/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9413333333333334
# Accuracy on the validation :	 0.846
# Starting epoch 64/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9457777777777778
# Accuracy on the validation :	 0.854
# Starting epoch 65/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9473333333333334
# Accuracy on the validation :	 0.846
# Starting epoch 66/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9428888888888889
# Accuracy on the validation :	 0.84
# Starting epoch 67/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9455555555555556
# Accuracy on the validation :	 0.844
# Starting epoch 68/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9457777777777778
# Accuracy on the validation :	 0.852
# Starting epoch 69/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9477777777777778
# Accuracy on the validation :	 0.842
# Starting epoch 70/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9457777777777778
# Accuracy on the validation :	 0.834
# Accuracy on the test :	 0.86
# STARTING FineTuning WITH GROUP:	 2
# Starting epoch 1/70, LR = [0.1]
# Accuracy on the training :	 0.2811111111111111
# Accuracy on the validation :	 0.179
# Starting epoch 2/70, LR = [0.1]
# Accuracy on the training :	 0.53
# Accuracy on the validation :	 0.278
# Starting epoch 3/70, LR = [0.1]
# Accuracy on the training :	 0.6328888888888888
# Accuracy on the validation :	 0.299
# Starting epoch 4/70, LR = [0.1]
# Accuracy on the training :	 0.6857777777777778
# Accuracy on the validation :	 0.322
# Starting epoch 5/70, LR = [0.1]
# Accuracy on the training :	 0.7004444444444444
# Accuracy on the validation :	 0.327
# Starting epoch 6/70, LR = [0.1]
# Accuracy on the training :	 0.7342222222222222
# Accuracy on the validation :	 0.363
# Starting epoch 7/70, LR = [0.1]
# Accuracy on the training :	 0.7448888888888889
# Accuracy on the validation :	 0.328
# Starting epoch 8/70, LR = [0.1]
# Accuracy on the training :	 0.7688888888888888
# Accuracy on the validation :	 0.31
# Starting epoch 9/70, LR = [0.1]
# Accuracy on the training :	 0.776
# Accuracy on the validation :	 0.311
# Starting epoch 10/70, LR = [0.1]
# Accuracy on the training :	 0.7946666666666666
# Accuracy on the validation :	 0.339
# Starting epoch 11/70, LR = [0.1]
# Accuracy on the training :	 0.8006666666666666
# Accuracy on the validation :	 0.359
# Starting epoch 12/70, LR = [0.1]
# Accuracy on the training :	 0.8182222222222222
# Accuracy on the validation :	 0.372
# Starting epoch 13/70, LR = [0.1]
# Accuracy on the training :	 0.8244444444444444
# Accuracy on the validation :	 0.374
# Starting epoch 14/70, LR = [0.1]
# Accuracy on the training :	 0.8197777777777778
# Accuracy on the validation :	 0.368
# Starting epoch 15/70, LR = [0.1]
# Accuracy on the training :	 0.8384444444444444
# Accuracy on the validation :	 0.381
# Starting epoch 16/70, LR = [0.1]
# Accuracy on the training :	 0.8317777777777777
# Accuracy on the validation :	 0.357
# Starting epoch 17/70, LR = [0.1]
# Accuracy on the training :	 0.8491111111111111
# Accuracy on the validation :	 0.365
# Starting epoch 18/70, LR = [0.1]
# Accuracy on the training :	 0.852
# Accuracy on the validation :	 0.35
# Starting epoch 19/70, LR = [0.1]
# Accuracy on the training :	 0.8548888888888889
# Accuracy on the validation :	 0.373
# Starting epoch 20/70, LR = [0.1]
# Accuracy on the training :	 0.86
# Accuracy on the validation :	 0.366
# Starting epoch 21/70, LR = [0.1]
# Accuracy on the training :	 0.856
# Accuracy on the validation :	 0.376
# Starting epoch 22/70, LR = [0.1]
# Accuracy on the training :	 0.8624444444444445
# Accuracy on the validation :	 0.379
# Starting epoch 23/70, LR = [0.1]
# Accuracy on the training :	 0.8722222222222222
# Accuracy on the validation :	 0.357
# Starting epoch 24/70, LR = [0.1]
# Accuracy on the training :	 0.8717777777777778
# Accuracy on the validation :	 0.373
# Starting epoch 25/70, LR = [0.1]
# Accuracy on the training :	 0.8791111111111111
# Accuracy on the validation :	 0.387
# Starting epoch 26/70, LR = [0.1]
# Accuracy on the training :	 0.8964444444444445
# Accuracy on the validation :	 0.393
# Starting epoch 27/70, LR = [0.1]
# Accuracy on the training :	 0.8948888888888888
# Accuracy on the validation :	 0.382
# Starting epoch 28/70, LR = [0.1]
# Accuracy on the training :	 0.894
# Accuracy on the validation :	 0.377
# Starting epoch 29/70, LR = [0.1]
# Accuracy on the training :	 0.8951111111111111
# Accuracy on the validation :	 0.388
# Starting epoch 30/70, LR = [0.1]
# Accuracy on the training :	 0.9084444444444445
# Accuracy on the validation :	 0.395
# Starting epoch 31/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9304444444444444
# Accuracy on the validation :	 0.406
# Starting epoch 32/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9482222222222222
# Accuracy on the validation :	 0.417
# Starting epoch 33/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9464444444444444
# Accuracy on the validation :	 0.403
# Starting epoch 34/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9524444444444444
# Accuracy on the validation :	 0.413
# Starting epoch 35/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9593333333333334
# Accuracy on the validation :	 0.412
# Starting epoch 36/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9553333333333334
# Accuracy on the validation :	 0.407
# Starting epoch 37/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9591111111111111
# Accuracy on the validation :	 0.416
# Starting epoch 38/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9644444444444444
# Accuracy on the validation :	 0.408
# Starting epoch 39/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9657777777777777
# Accuracy on the validation :	 0.409
# Starting epoch 40/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9631111111111111
# Accuracy on the validation :	 0.409
# Starting epoch 41/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9644444444444444
# Accuracy on the validation :	 0.42
# Starting epoch 42/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9682222222222222
# Accuracy on the validation :	 0.411
# Starting epoch 43/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.966
# Accuracy on the validation :	 0.409
# Starting epoch 44/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9671111111111111
# Accuracy on the validation :	 0.417
# Starting epoch 45/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9653333333333334
# Accuracy on the validation :	 0.414
# Starting epoch 46/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9682222222222222
# Accuracy on the validation :	 0.406
# Starting epoch 47/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.97
# Accuracy on the validation :	 0.414
# Starting epoch 48/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9686666666666667
# Accuracy on the validation :	 0.407
# Starting epoch 49/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9753333333333334
# Accuracy on the validation :	 0.42
# Starting epoch 50/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9731111111111111
# Accuracy on the validation :	 0.413
# Starting epoch 51/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.97
# Accuracy on the validation :	 0.404
# Starting epoch 52/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9722222222222222
# Accuracy on the validation :	 0.409
# Starting epoch 53/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.972
# Accuracy on the validation :	 0.416
# Starting epoch 54/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9731111111111111
# Accuracy on the validation :	 0.416
# Starting epoch 55/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9731111111111111
# Accuracy on the validation :	 0.411
# Starting epoch 56/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9751111111111112
# Accuracy on the validation :	 0.412
# Starting epoch 57/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9728888888888889
# Accuracy on the validation :	 0.42
# Starting epoch 58/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9744444444444444
# Accuracy on the validation :	 0.411
# Starting epoch 59/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9733333333333334
# Accuracy on the validation :	 0.415
# Starting epoch 60/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9731111111111111
# Accuracy on the validation :	 0.414
# Starting epoch 61/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9726666666666667
# Accuracy on the validation :	 0.411
# Starting epoch 62/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.972
# Accuracy on the validation :	 0.413
# Starting epoch 63/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9762222222222222
# Accuracy on the validation :	 0.408
# Starting epoch 64/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9735555555555555
# Accuracy on the validation :	 0.411
# Starting epoch 65/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9768888888888889
# Accuracy on the validation :	 0.413
# Starting epoch 66/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9713333333333334
# Accuracy on the validation :	 0.406
# Starting epoch 67/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9746666666666667
# Accuracy on the validation :	 0.418
# Starting epoch 68/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.974
# Accuracy on the validation :	 0.41
# Starting epoch 69/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9686666666666667
# Accuracy on the validation :	 0.417
# Starting epoch 70/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9726666666666667
# Accuracy on the validation :	 0.419
# Accuracy on the test :	 0.42
# STARTING FineTuning WITH GROUP:	 3
# Starting epoch 1/70, LR = [0.1]
# Accuracy on the training :	 0.09533333333333334
# Accuracy on the validation :	 0.05733333333333333
# Starting epoch 2/70, LR = [0.1]
# Accuracy on the training :	 0.22577777777777777
# Accuracy on the validation :	 0.088
# Starting epoch 3/70, LR = [0.1]
# Accuracy on the training :	 0.32911111111111113
# Accuracy on the validation :	 0.10333333333333333
# Starting epoch 4/70, LR = [0.1]
# Accuracy on the training :	 0.38177777777777777
# Accuracy on the validation :	 0.096
# Starting epoch 5/70, LR = [0.1]
# Accuracy on the training :	 0.4491111111111111
# Accuracy on the validation :	 0.15666666666666668
# Starting epoch 6/70, LR = [0.1]
# Accuracy on the training :	 0.5282222222222223
# Accuracy on the validation :	 0.16
# Starting epoch 7/70, LR = [0.1]
# Accuracy on the training :	 0.5773333333333334
# Accuracy on the validation :	 0.17866666666666667
# Starting epoch 8/70, LR = [0.1]
# Accuracy on the training :	 0.6251111111111111
# Accuracy on the validation :	 0.186
# Starting epoch 9/70, LR = [0.1]
# Accuracy on the training :	 0.6473333333333333
# Accuracy on the validation :	 0.19266666666666668
# Starting epoch 10/70, LR = [0.1]
# Accuracy on the training :	 0.6615555555555556
# Accuracy on the validation :	 0.18
# Starting epoch 11/70, LR = [0.1]
# Accuracy on the training :	 0.6897777777777778
# Accuracy on the validation :	 0.20066666666666666
# Starting epoch 12/70, LR = [0.1]
# Accuracy on the training :	 0.6993333333333334
# Accuracy on the validation :	 0.21933333333333332
# Starting epoch 13/70, LR = [0.1]
# Accuracy on the training :	 0.7351111111111112
# Accuracy on the validation :	 0.212
# Starting epoch 14/70, LR = [0.1]
# Accuracy on the training :	 0.7391111111111112
# Accuracy on the validation :	 0.21533333333333332
# Starting epoch 15/70, LR = [0.1]
# Accuracy on the training :	 0.7457777777777778
# Accuracy on the validation :	 0.21666666666666667
# Starting epoch 16/70, LR = [0.1]
# Accuracy on the training :	 0.7682222222222223
# Accuracy on the validation :	 0.20666666666666667
# Starting epoch 17/70, LR = [0.1]
# Accuracy on the training :	 0.7582222222222222
# Accuracy on the validation :	 0.22533333333333333
# Starting epoch 18/70, LR = [0.1]
# Accuracy on the training :	 0.7853333333333333
# Accuracy on the validation :	 0.23866666666666667
# Starting epoch 19/70, LR = [0.1]
# Accuracy on the training :	 0.7866666666666666
# Accuracy on the validation :	 0.218
# Starting epoch 20/70, LR = [0.1]
# Accuracy on the training :	 0.8006666666666666
# Accuracy on the validation :	 0.20333333333333334
# Starting epoch 21/70, LR = [0.1]
# Accuracy on the training :	 0.7937777777777778
# Accuracy on the validation :	 0.23266666666666666
# Starting epoch 22/70, LR = [0.1]
# Accuracy on the training :	 0.808
# Accuracy on the validation :	 0.23466666666666666
# Starting epoch 23/70, LR = [0.1]
# Accuracy on the training :	 0.8224444444444444
# Accuracy on the validation :	 0.23333333333333334
# Starting epoch 24/70, LR = [0.1]
# Accuracy on the training :	 0.8168888888888889
# Accuracy on the validation :	 0.246
# Starting epoch 25/70, LR = [0.1]
# Accuracy on the training :	 0.8235555555555556
# Accuracy on the validation :	 0.242
# Starting epoch 26/70, LR = [0.1]
# Accuracy on the training :	 0.8253333333333334
# Accuracy on the validation :	 0.23333333333333334
# Starting epoch 27/70, LR = [0.1]
# Accuracy on the training :	 0.8311111111111111
# Accuracy on the validation :	 0.236
# Starting epoch 28/70, LR = [0.1]
# Accuracy on the training :	 0.8457777777777777
# Accuracy on the validation :	 0.25066666666666665
# Starting epoch 29/70, LR = [0.1]
# Accuracy on the training :	 0.8442222222222222
# Accuracy on the validation :	 0.22733333333333333
# Starting epoch 30/70, LR = [0.1]
# Accuracy on the training :	 0.8446666666666667
# Accuracy on the validation :	 0.234
# Starting epoch 31/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.8737777777777778
# Accuracy on the validation :	 0.2633333333333333
# Starting epoch 32/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9135555555555556
# Accuracy on the validation :	 0.2633333333333333
# Starting epoch 33/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9133333333333333
# Accuracy on the validation :	 0.2786666666666667
# Starting epoch 34/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9237777777777778
# Accuracy on the validation :	 0.276
# Starting epoch 35/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9277777777777778
# Accuracy on the validation :	 0.27066666666666667
# Starting epoch 36/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9244444444444444
# Accuracy on the validation :	 0.272
# Starting epoch 37/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9328888888888889
# Accuracy on the validation :	 0.27
# Starting epoch 38/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9355555555555556
# Accuracy on the validation :	 0.27466666666666667
# Starting epoch 39/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9395555555555556
# Accuracy on the validation :	 0.2786666666666667
# Starting epoch 40/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9364444444444444
# Accuracy on the validation :	 0.27466666666666667
# Starting epoch 41/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9393333333333334
# Accuracy on the validation :	 0.27266666666666667
# Starting epoch 42/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9431111111111111
# Accuracy on the validation :	 0.276
# Starting epoch 43/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.944
# Accuracy on the validation :	 0.278
# Starting epoch 44/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9453333333333334
# Accuracy on the validation :	 0.2773333333333333
# Starting epoch 45/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9404444444444444
# Accuracy on the validation :	 0.268
# Starting epoch 46/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.954
# Accuracy on the validation :	 0.27466666666666667
# Starting epoch 47/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9466666666666667
# Accuracy on the validation :	 0.2773333333333333
# Starting epoch 48/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9424444444444444
# Accuracy on the validation :	 0.27066666666666667
# Starting epoch 49/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9515555555555556
# Accuracy on the validation :	 0.278
# Starting epoch 50/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9508888888888889
# Accuracy on the validation :	 0.2653333333333333
# Starting epoch 51/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9515555555555556
# Accuracy on the validation :	 0.2733333333333333
# Starting epoch 52/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9488888888888889
# Accuracy on the validation :	 0.268
# Starting epoch 53/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9493333333333334
# Accuracy on the validation :	 0.27066666666666667
# Starting epoch 54/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.956
# Accuracy on the validation :	 0.27066666666666667
# Starting epoch 55/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9562222222222222
# Accuracy on the validation :	 0.2713333333333333
# Starting epoch 56/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9504444444444444
# Accuracy on the validation :	 0.282
# Starting epoch 57/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9568888888888889
# Accuracy on the validation :	 0.2786666666666667
# Starting epoch 58/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.956
# Accuracy on the validation :	 0.272
# Starting epoch 59/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9564444444444444
# Accuracy on the validation :	 0.27666666666666667
# Starting epoch 60/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9524444444444444
# Accuracy on the validation :	 0.26866666666666666
# Starting epoch 61/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9504444444444444
# Accuracy on the validation :	 0.2786666666666667
# Starting epoch 62/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9546666666666667
# Accuracy on the validation :	 0.2733333333333333
# Starting epoch 63/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9504444444444444
# Accuracy on the validation :	 0.2713333333333333
# Starting epoch 64/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9504444444444444
# Accuracy on the validation :	 0.2673333333333333
# Starting epoch 65/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9546666666666667
# Accuracy on the validation :	 0.2733333333333333
# Starting epoch 66/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9517777777777777
# Accuracy on the validation :	 0.266
# Starting epoch 67/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9588888888888889
# Accuracy on the validation :	 0.272
# Starting epoch 68/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9484444444444444
# Accuracy on the validation :	 0.276
# Starting epoch 69/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9524444444444444
# Accuracy on the validation :	 0.27466666666666667
# Starting epoch 70/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9566666666666667
# Accuracy on the validation :	 0.27066666666666667
# Accuracy on the test :	 0.27
# STARTING FineTuning WITH GROUP:	 4
# Starting epoch 1/70, LR = [0.1]
# Accuracy on the training :	 0.015333333333333332
# Accuracy on the validation :	 0.025
# Starting epoch 2/70, LR = [0.1]
# Accuracy on the training :	 0.15955555555555556
# Accuracy on the validation :	 0.059
# Starting epoch 3/70, LR = [0.1]
# Accuracy on the training :	 0.25933333333333336
# Accuracy on the validation :	 0.072
# Starting epoch 4/70, LR = [0.1]
# Accuracy on the training :	 0.33266666666666667
# Accuracy on the validation :	 0.0665
# Starting epoch 5/70, LR = [0.1]
# Accuracy on the training :	 0.37866666666666665
# Accuracy on the validation :	 0.104
# Starting epoch 6/70, LR = [0.1]
# Accuracy on the training :	 0.43177777777777776
# Accuracy on the validation :	 0.1075
# Starting epoch 7/70, LR = [0.1]
# Accuracy on the training :	 0.4568888888888889
# Accuracy on the validation :	 0.099
# Starting epoch 8/70, LR = [0.1]
# Accuracy on the training :	 0.504
# Accuracy on the validation :	 0.098
# Starting epoch 9/70, LR = [0.1]
# Accuracy on the training :	 0.5257777777777778
# Accuracy on the validation :	 0.0845
# Starting epoch 10/70, LR = [0.1]
# Accuracy on the training :	 0.5804444444444444
# Accuracy on the validation :	 0.1395
# Starting epoch 11/70, LR = [0.1]
# Accuracy on the training :	 0.5935555555555555
# Accuracy on the validation :	 0.156
# Starting epoch 12/70, LR = [0.1]
# Accuracy on the training :	 0.6244444444444445
# Accuracy on the validation :	 0.139
# Starting epoch 13/70, LR = [0.1]
# Accuracy on the training :	 0.6395555555555555
# Accuracy on the validation :	 0.144
# Starting epoch 14/70, LR = [0.1]
# Accuracy on the training :	 0.6751111111111111
# Accuracy on the validation :	 0.143
# Starting epoch 15/70, LR = [0.1]
# Accuracy on the training :	 0.69
# Accuracy on the validation :	 0.1465
# Starting epoch 16/70, LR = [0.1]
# Accuracy on the training :	 0.7177777777777777
# Accuracy on the validation :	 0.1445
# Starting epoch 17/70, LR = [0.1]
# Accuracy on the training :	 0.7071111111111111
# Accuracy on the validation :	 0.16
# Starting epoch 18/70, LR = [0.1]
# Accuracy on the training :	 0.7393333333333333
# Accuracy on the validation :	 0.17
# Starting epoch 19/70, LR = [0.1]
# Accuracy on the training :	 0.7293333333333333
# Accuracy on the validation :	 0.168
# Starting epoch 20/70, LR = [0.1]
# Accuracy on the training :	 0.748
# Accuracy on the validation :	 0.168
# Starting epoch 21/70, LR = [0.1]
# Accuracy on the training :	 0.7722222222222223
# Accuracy on the validation :	 0.181
# Starting epoch 22/70, LR = [0.1]
# Accuracy on the training :	 0.7744444444444445
# Accuracy on the validation :	 0.178
# Starting epoch 23/70, LR = [0.1]
# Accuracy on the training :	 0.788
# Accuracy on the validation :	 0.165
# Starting epoch 24/70, LR = [0.1]
# Accuracy on the training :	 0.7733333333333333
# Accuracy on the validation :	 0.167
# Starting epoch 25/70, LR = [0.1]
# Accuracy on the training :	 0.7986666666666666
# Accuracy on the validation :	 0.18
# Starting epoch 26/70, LR = [0.1]
# Accuracy on the training :	 0.8088888888888889
# Accuracy on the validation :	 0.172
# Starting epoch 27/70, LR = [0.1]
# Accuracy on the training :	 0.8004444444444444
# Accuracy on the validation :	 0.1845
# Starting epoch 28/70, LR = [0.1]
# Accuracy on the training :	 0.8128888888888889
# Accuracy on the validation :	 0.177
# Starting epoch 29/70, LR = [0.1]
# Accuracy on the training :	 0.8008888888888889
# Accuracy on the validation :	 0.1785
# Starting epoch 30/70, LR = [0.1]
# Accuracy on the training :	 0.8097777777777778
# Accuracy on the validation :	 0.1935
# Starting epoch 31/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.8595555555555555
# Accuracy on the validation :	 0.2005
# Starting epoch 32/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.8842222222222222
# Accuracy on the validation :	 0.2005
# Starting epoch 33/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.8886666666666667
# Accuracy on the validation :	 0.202
# Starting epoch 34/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.8855555555555555
# Accuracy on the validation :	 0.201
# Starting epoch 35/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.8917777777777778
# Accuracy on the validation :	 0.1955
# Starting epoch 36/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.8951111111111111
# Accuracy on the validation :	 0.202
# Starting epoch 37/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.8982222222222223
# Accuracy on the validation :	 0.2045
# Starting epoch 38/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.8973333333333333
# Accuracy on the validation :	 0.2015
# Starting epoch 39/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9004444444444445
# Accuracy on the validation :	 0.2015
# Starting epoch 40/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9033333333333333
# Accuracy on the validation :	 0.203
# Starting epoch 41/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9035555555555556
# Accuracy on the validation :	 0.204
# Starting epoch 42/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9031111111111111
# Accuracy on the validation :	 0.1995
# Starting epoch 43/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9066666666666666
# Accuracy on the validation :	 0.199
# Starting epoch 44/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9135555555555556
# Accuracy on the validation :	 0.198
# Starting epoch 45/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.912
# Accuracy on the validation :	 0.2
# Starting epoch 46/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9191111111111111
# Accuracy on the validation :	 0.2045
# Starting epoch 47/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.922
# Accuracy on the validation :	 0.2075
# Starting epoch 48/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.914
# Accuracy on the validation :	 0.1985
# Starting epoch 49/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.914
# Accuracy on the validation :	 0.1985
# Starting epoch 50/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9233333333333333
# Accuracy on the validation :	 0.202
# Starting epoch 51/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9175555555555556
# Accuracy on the validation :	 0.1995
# Starting epoch 52/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9195555555555556
# Accuracy on the validation :	 0.2025
# Starting epoch 53/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9193333333333333
# Accuracy on the validation :	 0.2015
# Starting epoch 54/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9222222222222223
# Accuracy on the validation :	 0.204
# Starting epoch 55/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9171111111111111
# Accuracy on the validation :	 0.2
# Starting epoch 56/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9166666666666666
# Accuracy on the validation :	 0.1985
# Starting epoch 57/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.92
# Accuracy on the validation :	 0.2
# Starting epoch 58/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9193333333333333
# Accuracy on the validation :	 0.203
# Starting epoch 59/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9211111111111111
# Accuracy on the validation :	 0.197
# Starting epoch 60/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9211111111111111
# Accuracy on the validation :	 0.202
# Starting epoch 61/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9197777777777778
# Accuracy on the validation :	 0.2005
# Starting epoch 62/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9246666666666666
# Accuracy on the validation :	 0.198
# Starting epoch 63/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.922
# Accuracy on the validation :	 0.2045
# Starting epoch 64/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9231111111111111
# Accuracy on the validation :	 0.2015
# Starting epoch 65/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9166666666666666
# Accuracy on the validation :	 0.202
# Starting epoch 66/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9262222222222222
# Accuracy on the validation :	 0.203
# Starting epoch 67/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9237777777777778
# Accuracy on the validation :	 0.2005
# Starting epoch 68/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9211111111111111
# Accuracy on the validation :	 0.1985
# Starting epoch 69/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9186666666666666
# Accuracy on the validation :	 0.2065
# Starting epoch 70/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9217777777777778
# Accuracy on the validation :	 0.2005
# Accuracy on the test :	 0.19475
# STARTING FineTuning WITH GROUP:	 5
# Starting epoch 1/70, LR = [0.1]
# Accuracy on the training :	 0.06711111111111111
# Accuracy on the validation :	 0.0492
# Starting epoch 2/70, LR = [0.1]
# Accuracy on the training :	 0.326
# Accuracy on the validation :	 0.0792
# Starting epoch 3/70, LR = [0.1]
# Accuracy on the training :	 0.48133333333333334
# Accuracy on the validation :	 0.0956
# Starting epoch 4/70, LR = [0.1]
# Accuracy on the training :	 0.5486666666666666
# Accuracy on the validation :	 0.1
# Starting epoch 5/70, LR = [0.1]
# Accuracy on the training :	 0.5946666666666667
# Accuracy on the validation :	 0.1176
# Starting epoch 6/70, LR = [0.1]
# Accuracy on the training :	 0.6333333333333333
# Accuracy on the validation :	 0.1112
# Starting epoch 7/70, LR = [0.1]
# Accuracy on the training :	 0.6648888888888889
# Accuracy on the validation :	 0.1288
# Starting epoch 8/70, LR = [0.1]
# Accuracy on the training :	 0.7055555555555556
# Accuracy on the validation :	 0.1192
# Starting epoch 9/70, LR = [0.1]
# Accuracy on the training :	 0.726
# Accuracy on the validation :	 0.1316
# Starting epoch 10/70, LR = [0.1]
# Accuracy on the training :	 0.7393333333333333
# Accuracy on the validation :	 0.1296
# Starting epoch 11/70, LR = [0.1]
# Accuracy on the training :	 0.762
# Accuracy on the validation :	 0.1304
# Starting epoch 12/70, LR = [0.1]
# Accuracy on the training :	 0.7735555555555556
# Accuracy on the validation :	 0.1324
# Starting epoch 13/70, LR = [0.1]
# Accuracy on the training :	 0.7891111111111111
# Accuracy on the validation :	 0.1468
# Starting epoch 14/70, LR = [0.1]
# Accuracy on the training :	 0.8093333333333333
# Accuracy on the validation :	 0.1464
# Starting epoch 15/70, LR = [0.1]
# Accuracy on the training :	 0.8044444444444444
# Accuracy on the validation :	 0.1492
# Starting epoch 16/70, LR = [0.1]
# Accuracy on the training :	 0.8057777777777778
# Accuracy on the validation :	 0.148
# Starting epoch 17/70, LR = [0.1]
# Accuracy on the training :	 0.8175555555555556
# Accuracy on the validation :	 0.1304
# Starting epoch 18/70, LR = [0.1]
# Accuracy on the training :	 0.8304444444444444
# Accuracy on the validation :	 0.1436
# Starting epoch 19/70, LR = [0.1]
# Accuracy on the training :	 0.8277777777777777
# Accuracy on the validation :	 0.1472
# Starting epoch 20/70, LR = [0.1]
# Accuracy on the training :	 0.8517777777777777
# Accuracy on the validation :	 0.1304
# Starting epoch 21/70, LR = [0.1]
# Accuracy on the training :	 0.8502222222222222
# Accuracy on the validation :	 0.1268
# Starting epoch 22/70, LR = [0.1]
# Accuracy on the training :	 0.8635555555555555
# Accuracy on the validation :	 0.1544
# Starting epoch 23/70, LR = [0.1]
# Accuracy on the training :	 0.8495555555555555
# Accuracy on the validation :	 0.1424
# Starting epoch 24/70, LR = [0.1]
# Accuracy on the training :	 0.8648888888888889
# Accuracy on the validation :	 0.1296
# Starting epoch 25/70, LR = [0.1]
# Accuracy on the training :	 0.8815555555555555
# Accuracy on the validation :	 0.13
# Starting epoch 26/70, LR = [0.1]
# Accuracy on the training :	 0.8748888888888889
# Accuracy on the validation :	 0.1468
# Starting epoch 27/70, LR = [0.1]
# Accuracy on the training :	 0.8857777777777778
# Accuracy on the validation :	 0.1548
# Starting epoch 28/70, LR = [0.1]
# Accuracy on the training :	 0.8908888888888888
# Accuracy on the validation :	 0.1264
# Starting epoch 29/70, LR = [0.1]
# Accuracy on the training :	 0.89
# Accuracy on the validation :	 0.1568
# Starting epoch 30/70, LR = [0.1]
# Accuracy on the training :	 0.89
# Accuracy on the validation :	 0.152
# Starting epoch 31/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9175555555555556
# Accuracy on the validation :	 0.17
# Starting epoch 32/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9426666666666667
# Accuracy on the validation :	 0.1688
# Starting epoch 33/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9475555555555556
# Accuracy on the validation :	 0.1712
# Starting epoch 34/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.948
# Accuracy on the validation :	 0.1676
# Starting epoch 35/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9488888888888889
# Accuracy on the validation :	 0.1732
# Starting epoch 36/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9511111111111111
# Accuracy on the validation :	 0.1716
# Starting epoch 37/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.954
# Accuracy on the validation :	 0.1712
# Starting epoch 38/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9584444444444444
# Accuracy on the validation :	 0.1708
# Starting epoch 39/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9597777777777777
# Accuracy on the validation :	 0.1688
# Starting epoch 40/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9617777777777777
# Accuracy on the validation :	 0.1696
# Starting epoch 41/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9657777777777777
# Accuracy on the validation :	 0.1704
# Starting epoch 42/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9582222222222222
# Accuracy on the validation :	 0.1724
# Starting epoch 43/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9664444444444444
# Accuracy on the validation :	 0.1688
# Starting epoch 44/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9626666666666667
# Accuracy on the validation :	 0.1672
# Starting epoch 45/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9624444444444444
# Accuracy on the validation :	 0.1704
# Starting epoch 46/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9715555555555555
# Accuracy on the validation :	 0.17
# Starting epoch 47/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9713333333333334
# Accuracy on the validation :	 0.1692
# Starting epoch 48/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9655555555555555
# Accuracy on the validation :	 0.168
# Starting epoch 49/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9657777777777777
# Accuracy on the validation :	 0.1708
# Starting epoch 50/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9675555555555555
# Accuracy on the validation :	 0.1704
# Starting epoch 51/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9684444444444444
# Accuracy on the validation :	 0.172
# Starting epoch 52/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9655555555555555
# Accuracy on the validation :	 0.17
# Starting epoch 53/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9682222222222222
# Accuracy on the validation :	 0.1704
# Starting epoch 54/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.968
# Accuracy on the validation :	 0.174
# Starting epoch 55/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9697777777777777
# Accuracy on the validation :	 0.1748
# Starting epoch 56/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9695555555555555
# Accuracy on the validation :	 0.1704
# Starting epoch 57/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9688888888888889
# Accuracy on the validation :	 0.1712
# Starting epoch 58/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9695555555555555
# Accuracy on the validation :	 0.1712
# Starting epoch 59/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9704444444444444
# Accuracy on the validation :	 0.172
# Starting epoch 60/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9706666666666667
# Accuracy on the validation :	 0.1708
# Starting epoch 61/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9684444444444444
# Accuracy on the validation :	 0.1708
# Starting epoch 62/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.972
# Accuracy on the validation :	 0.1724
# Starting epoch 63/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9693333333333334
# Accuracy on the validation :	 0.1704
# Starting epoch 64/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9695555555555555
# Accuracy on the validation :	 0.172
# Starting epoch 65/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9675555555555555
# Accuracy on the validation :	 0.1748
# Starting epoch 66/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9686666666666667
# Accuracy on the validation :	 0.1708
# Starting epoch 67/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9697777777777777
# Accuracy on the validation :	 0.1748
# Starting epoch 68/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9715555555555555
# Accuracy on the validation :	 0.1684
# Starting epoch 69/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9677777777777777
# Accuracy on the validation :	 0.17
# Starting epoch 70/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9702222222222222
# Accuracy on the validation :	 0.1732
# Accuracy on the test :	 0.1712
# STARTING FineTuning WITH GROUP:	 6
# Starting epoch 1/70, LR = [0.1]
# Accuracy on the training :	 0.06866666666666667
# Accuracy on the validation :	 0.035666666666666666
# Starting epoch 2/70, LR = [0.1]
# Accuracy on the training :	 0.32133333333333336
# Accuracy on the validation :	 0.06133333333333333
# Starting epoch 3/70, LR = [0.1]
# Accuracy on the training :	 0.44355555555555554
# Accuracy on the validation :	 0.08066666666666666
# Starting epoch 4/70, LR = [0.1]
# Accuracy on the training :	 0.5093333333333333
# Accuracy on the validation :	 0.085
# Starting epoch 5/70, LR = [0.1]
# Accuracy on the training :	 0.56
# Accuracy on the validation :	 0.08866666666666667
# Starting epoch 6/70, LR = [0.1]
# Accuracy on the training :	 0.6035555555555555
# Accuracy on the validation :	 0.09
# Starting epoch 7/70, LR = [0.1]
# Accuracy on the training :	 0.6393333333333333
# Accuracy on the validation :	 0.105
# Starting epoch 8/70, LR = [0.1]
# Accuracy on the training :	 0.668
# Accuracy on the validation :	 0.11466666666666667
# Starting epoch 9/70, LR = [0.1]
# Accuracy on the training :	 0.6973333333333334
# Accuracy on the validation :	 0.109
# Starting epoch 10/70, LR = [0.1]
# Accuracy on the training :	 0.7002222222222222
# Accuracy on the validation :	 0.09366666666666666
# Starting epoch 11/70, LR = [0.1]
# Accuracy on the training :	 0.7202222222222222
# Accuracy on the validation :	 0.1
# Starting epoch 12/70, LR = [0.1]
# Accuracy on the training :	 0.7433333333333333
# Accuracy on the validation :	 0.10733333333333334
# Starting epoch 13/70, LR = [0.1]
# Accuracy on the training :	 0.7513333333333333
# Accuracy on the validation :	 0.103
# Starting epoch 14/70, LR = [0.1]
# Accuracy on the training :	 0.7697777777777778
# Accuracy on the validation :	 0.11433333333333333
# Starting epoch 15/70, LR = [0.1]
# Accuracy on the training :	 0.784
# Accuracy on the validation :	 0.11733333333333333
# Starting epoch 16/70, LR = [0.1]
# Accuracy on the training :	 0.7908888888888889
# Accuracy on the validation :	 0.11566666666666667
# Starting epoch 17/70, LR = [0.1]
# Accuracy on the training :	 0.8091111111111111
# Accuracy on the validation :	 0.121
# Starting epoch 18/70, LR = [0.1]
# Accuracy on the training :	 0.8026666666666666
# Accuracy on the validation :	 0.12533333333333332
# Starting epoch 19/70, LR = [0.1]
# Accuracy on the training :	 0.8215555555555556
# Accuracy on the validation :	 0.12433333333333334
# Starting epoch 20/70, LR = [0.1]
# Accuracy on the training :	 0.814
# Accuracy on the validation :	 0.10866666666666666
# Starting epoch 21/70, LR = [0.1]
# Accuracy on the training :	 0.8231111111111111
# Accuracy on the validation :	 0.12566666666666668
# Starting epoch 22/70, LR = [0.1]
# Accuracy on the training :	 0.8355555555555556
# Accuracy on the validation :	 0.12933333333333333
# Starting epoch 23/70, LR = [0.1]
# Accuracy on the training :	 0.8424444444444444
# Accuracy on the validation :	 0.105
# Starting epoch 24/70, LR = [0.1]
# Accuracy on the training :	 0.8455555555555555
# Accuracy on the validation :	 0.12433333333333334
# Starting epoch 25/70, LR = [0.1]
# Accuracy on the training :	 0.8573333333333333
# Accuracy on the validation :	 0.10633333333333334
# Starting epoch 26/70, LR = [0.1]
# Accuracy on the training :	 0.8566666666666667
# Accuracy on the validation :	 0.11866666666666667
# Starting epoch 27/70, LR = [0.1]
# Accuracy on the training :	 0.8511111111111112
# Accuracy on the validation :	 0.11633333333333333
# ...
# Accuracy on the validation :	 0.08733333333333333
# Starting epoch 21/70, LR = [0.1]
# Accuracy on the training :	 0.8695555555555555
# Accuracy on the validation :	 0.09222222222222222
# Starting epoch 22/70, LR = [0.1]
# Accuracy on the training :	 0.8793333333333333
# Accuracy on the validation :	 0.07977777777777778
# Starting epoch 23/70, LR = [0.1]
# Accuracy on the training :	 0.8795555555555555
# Accuracy on the validation :	 0.08733333333333333
# Starting epoch 24/70, LR = [0.1]
# Accuracy on the training :	 0.8853333333333333
# Accuracy on the validation :	 0.08333333333333333
# Starting epoch 25/70, LR = [0.1]
# Accuracy on the training :	 0.8833333333333333
# Accuracy on the validation :	 0.086
# Starting epoch 26/70, LR = [0.1]
# Accuracy on the training :	 0.8964444444444445
# Accuracy on the validation :	 0.08977777777777778
# Starting epoch 27/70, LR = [0.1]
# Accuracy on the training :	 0.894
# Accuracy on the validation :	 0.088
# Starting epoch 28/70, LR = [0.1]
# Accuracy on the training :	 0.8955555555555555
# Accuracy on the validation :	 0.09066666666666667
# Starting epoch 29/70, LR = [0.1]
# Accuracy on the training :	 0.894
# Accuracy on the validation :	 0.07977777777777778
# Starting epoch 30/70, LR = [0.1]
# Accuracy on the training :	 0.8955555555555555
# Accuracy on the validation :	 0.08244444444444445
# Starting epoch 31/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.928
# Accuracy on the validation :	 0.09422222222222222
# Starting epoch 32/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9491111111111111
# Accuracy on the validation :	 0.09577777777777778
# Starting epoch 33/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.954
# Accuracy on the validation :	 0.09444444444444444
# Starting epoch 34/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9588888888888889
# Accuracy on the validation :	 0.09555555555555556
# Starting epoch 35/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9591111111111111
# Accuracy on the validation :	 0.09777777777777778
# Starting epoch 36/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9637777777777777
# Accuracy on the validation :	 0.09755555555555556
# Starting epoch 37/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9644444444444444
# Accuracy on the validation :	 0.09622222222222222
# Starting epoch 38/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9668888888888889
# Accuracy on the validation :	 0.098
# Starting epoch 39/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.964
# Accuracy on the validation :	 0.09555555555555556
# Starting epoch 40/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9675555555555555
# Accuracy on the validation :	 0.09777777777777778
# Starting epoch 41/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9666666666666667
# Accuracy on the validation :	 0.098
# Starting epoch 42/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9702222222222222
# Accuracy on the validation :	 0.09844444444444445
# Starting epoch 43/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9748888888888889
# Accuracy on the validation :	 0.096
# Starting epoch 44/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9726666666666667
# Accuracy on the validation :	 0.09577777777777778
# Starting epoch 45/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9693333333333334
# Accuracy on the validation :	 0.09733333333333333
# Starting epoch 46/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9731111111111111
# Accuracy on the validation :	 0.09555555555555556
# Starting epoch 47/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9737777777777777
# Accuracy on the validation :	 0.09555555555555556
# Starting epoch 48/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9744444444444444
# Accuracy on the validation :	 0.09666666666666666
# Starting epoch 49/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9706666666666667
# Accuracy on the validation :	 0.096
# Starting epoch 50/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9762222222222222
# Accuracy on the validation :	 0.09733333333333333
# Starting epoch 51/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9735555555555555
# Accuracy on the validation :	 0.09733333333333333
# Starting epoch 52/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9764444444444444
# Accuracy on the validation :	 0.09622222222222222
# Starting epoch 53/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9717777777777777
# Accuracy on the validation :	 0.098
# Starting epoch 54/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9708888888888889
# Accuracy on the validation :	 0.09844444444444445
# Starting epoch 55/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9728888888888889
# Accuracy on the validation :	 0.09688888888888889
# Starting epoch 56/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9737777777777777
# Accuracy on the validation :	 0.09733333333333333
# Starting epoch 57/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9757777777777777
# Accuracy on the validation :	 0.09822222222222222
# Starting epoch 58/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9757777777777777
# Accuracy on the validation :	 0.09822222222222222
# Starting epoch 59/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9753333333333334
# Accuracy on the validation :	 0.09666666666666666
# Starting epoch 60/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9728888888888889
# Accuracy on the validation :	 0.09577777777777778
# Starting epoch 61/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9757777777777777
# Accuracy on the validation :	 0.0951111111111111
# Starting epoch 62/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9733333333333334
# Accuracy on the validation :	 0.09488888888888888
# Starting epoch 63/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9731111111111111
# Accuracy on the validation :	 0.09733333333333333
# Starting epoch 64/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9766666666666667
# Accuracy on the validation :	 0.09844444444444445
# Starting epoch 65/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9771111111111112
# Accuracy on the validation :	 0.09577777777777778
# Starting epoch 66/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9735555555555555
# Accuracy on the validation :	 0.09733333333333333
# Starting epoch 67/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9773333333333334
# Accuracy on the validation :	 0.09777777777777778
# Starting epoch 68/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9744444444444444
# Accuracy on the validation :	 0.09755555555555556
# Starting epoch 69/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9757777777777777
# Accuracy on the validation :	 0.09777777777777778
# Starting epoch 70/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9744444444444444
# Accuracy on the validation :	 0.09555555555555556
# Accuracy on the test :	 0.095
# STARTING FineTuning WITH GROUP:	 10
# Starting epoch 1/70, LR = [0.1]
# Accuracy on the training :	 0.056666666666666664
# Accuracy on the validation :	 0.0172
# Starting epoch 2/70, LR = [0.1]
# Accuracy on the training :	 0.31244444444444447
# Accuracy on the validation :	 0.0302
# Starting epoch 3/70, LR = [0.1]
# Accuracy on the training :	 0.39155555555555555
# Accuracy on the validation :	 0.0368
# Starting epoch 4/70, LR = [0.1]
# Accuracy on the training :	 0.4826666666666667
# Accuracy on the validation :	 0.0392
# Starting epoch 5/70, LR = [0.1]
# Accuracy on the training :	 0.5904444444444444
# Accuracy on the validation :	 0.0584
# Starting epoch 6/70, LR = [0.1]
# Accuracy on the training :	 0.64
# Accuracy on the validation :	 0.055
# Starting epoch 7/70, LR = [0.1]
# Accuracy on the training :	 0.666
# Accuracy on the validation :	 0.066
# Starting epoch 8/70, LR = [0.1]
# Accuracy on the training :	 0.7093333333333334
# Accuracy on the validation :	 0.0646
# Starting epoch 9/70, LR = [0.1]
# Accuracy on the training :	 0.7333333333333333
# Accuracy on the validation :	 0.0606
# Starting epoch 10/70, LR = [0.1]
# Accuracy on the training :	 0.7337777777777778
# Accuracy on the validation :	 0.0726
# Starting epoch 11/70, LR = [0.1]
# Accuracy on the training :	 0.754
# Accuracy on the validation :	 0.0636
# Starting epoch 12/70, LR = [0.1]
# Accuracy on the training :	 0.7768888888888889
# Accuracy on the validation :	 0.0658
# Starting epoch 13/70, LR = [0.1]
# Accuracy on the training :	 0.7848888888888889
# Accuracy on the validation :	 0.0702
# Starting epoch 14/70, LR = [0.1]
# Accuracy on the training :	 0.7953333333333333
# Accuracy on the validation :	 0.0734
# Starting epoch 15/70, LR = [0.1]
# Accuracy on the training :	 0.802
# Accuracy on the validation :	 0.0728
# Starting epoch 16/70, LR = [0.1]
# Accuracy on the training :	 0.8122222222222222
# Accuracy on the validation :	 0.0706
# Starting epoch 17/70, LR = [0.1]
# Accuracy on the training :	 0.8255555555555556
# Accuracy on the validation :	 0.072
# Starting epoch 18/70, LR = [0.1]
# Accuracy on the training :	 0.8255555555555556
# Accuracy on the validation :	 0.067
# Starting epoch 19/70, LR = [0.1]
# Accuracy on the training :	 0.8333333333333334
# Accuracy on the validation :	 0.0774
# Starting epoch 20/70, LR = [0.1]
# Accuracy on the training :	 0.8297777777777777
# Accuracy on the validation :	 0.076
# Starting epoch 21/70, LR = [0.1]
# Accuracy on the training :	 0.8242222222222222
# Accuracy on the validation :	 0.0652
# Starting epoch 22/70, LR = [0.1]
# Accuracy on the training :	 0.862
# Accuracy on the validation :	 0.0738
# Starting epoch 23/70, LR = [0.1]
# Accuracy on the training :	 0.846
# Accuracy on the validation :	 0.077
# Starting epoch 24/70, LR = [0.1]
# Accuracy on the training :	 0.8595555555555555
# Accuracy on the validation :	 0.076
# Starting epoch 25/70, LR = [0.1]
# Accuracy on the training :	 0.8568888888888889
# Accuracy on the validation :	 0.0742
# Starting epoch 26/70, LR = [0.1]
# Accuracy on the training :	 0.8682222222222222
# Accuracy on the validation :	 0.078
# Starting epoch 27/70, LR = [0.1]
# Accuracy on the training :	 0.8655555555555555
# Accuracy on the validation :	 0.0702
# Starting epoch 28/70, LR = [0.1]
# Accuracy on the training :	 0.8628888888888889
# Accuracy on the validation :	 0.0738
# Starting epoch 29/70, LR = [0.1]
# Accuracy on the training :	 0.8768888888888889
# Accuracy on the validation :	 0.0756
# Starting epoch 30/70, LR = [0.1]
# Accuracy on the training :	 0.8733333333333333
# Accuracy on the validation :	 0.0686
# Starting epoch 31/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9044444444444445
# Accuracy on the validation :	 0.082
# Starting epoch 32/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9275555555555556
# Accuracy on the validation :	 0.0808
# Starting epoch 33/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9326666666666666
# Accuracy on the validation :	 0.0832
# Starting epoch 34/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9384444444444444
# Accuracy on the validation :	 0.082
# Starting epoch 35/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9408888888888889
# Accuracy on the validation :	 0.0838
# Starting epoch 36/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9442222222222222
# Accuracy on the validation :	 0.0836
# Starting epoch 37/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9408888888888889
# Accuracy on the validation :	 0.0832
# Starting epoch 38/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9453333333333334
# Accuracy on the validation :	 0.0816
# Starting epoch 39/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.95
# Accuracy on the validation :	 0.0828
# Starting epoch 40/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9515555555555556
# Accuracy on the validation :	 0.0832
# Starting epoch 41/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9533333333333334
# Accuracy on the validation :	 0.0828
# Starting epoch 42/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9502222222222222
# Accuracy on the validation :	 0.0828
# Starting epoch 43/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9555555555555556
# Accuracy on the validation :	 0.0824
# Starting epoch 44/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.9553333333333334
# Accuracy on the validation :	 0.0842
# Starting epoch 45/70, LR = [0.010000000000000002]
# Accuracy on the training :	 0.954
# Accuracy on the validation :	 0.082
# Starting epoch 46/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9608888888888889
# Accuracy on the validation :	 0.0834
# Starting epoch 47/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9562222222222222
# Accuracy on the validation :	 0.0838
# Starting epoch 48/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9586666666666667
# Accuracy on the validation :	 0.0828
# Starting epoch 49/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9604444444444444
# Accuracy on the validation :	 0.0832
# Starting epoch 50/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9611111111111111
# Accuracy on the validation :	 0.0846
# Starting epoch 51/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9571111111111111
# Accuracy on the validation :	 0.0838
# Starting epoch 52/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9593333333333334
# Accuracy on the validation :	 0.0828
# Starting epoch 53/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9584444444444444
# Accuracy on the validation :	 0.0826
# Starting epoch 54/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9613333333333334
# Accuracy on the validation :	 0.0822
# Starting epoch 55/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9604444444444444
# Accuracy on the validation :	 0.0822
# Starting epoch 56/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9642222222222222
# Accuracy on the validation :	 0.0826
# Starting epoch 57/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9633333333333334
# Accuracy on the validation :	 0.0838
# Starting epoch 58/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9617777777777777
# Accuracy on the validation :	 0.0812
# Starting epoch 59/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9595555555555556
# Accuracy on the validation :	 0.0822
# Starting epoch 60/70, LR = [0.0010000000000000002]
# Accuracy on the training :	 0.9628888888888889
# Accuracy on the validation :	 0.084
# Starting epoch 61/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9555555555555556
# Accuracy on the validation :	 0.0842
# Starting epoch 62/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9628888888888889
# Accuracy on the validation :	 0.0856
# Starting epoch 63/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9606666666666667
# Accuracy on the validation :	 0.084
# Starting epoch 64/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9622222222222222
# Accuracy on the validation :	 0.083
# Starting epoch 65/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9622222222222222
# Accuracy on the validation :	 0.082
# Starting epoch 66/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9602222222222222
# Accuracy on the validation :	 0.0836
# Starting epoch 67/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9613333333333334
# Accuracy on the validation :	 0.0836
# Starting epoch 68/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9628888888888889
# Accuracy on the validation :	 0.0824
# Starting epoch 69/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.9626666666666667
# Accuracy on the validation :	 0.0814
# Starting epoch 70/70, LR = [0.00010000000000000003]
# Accuracy on the training :	 0.964
# Accuracy on the validation :	 0.0832
# Accuracy on the test :	 0.0858
