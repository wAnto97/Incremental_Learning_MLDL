# %%
# %matplotlib notebook
from src.Utils import Utils
import matplotlib.pyplot as plt
import numpy as np

# fig,ax = plt.subplots(figsize=(7,5))
utils = Utils()
data = utils.readFileMetrics('./results/LwF/LwFMetrics_plateau.json',report = True)
# ax.plot(np.arange(10,110, 10),data[1],marker='^',color='green')
# plt.ylabel('Accuracy')
# plt.xlabel('n_classes')
# plt.title('LwF on plateau')
# # plt.ylim([0,1])
# # plt.grid(ydata=np.arange(0,1,0.01))
# major_ticks = np.arange(0, 1.1, 0.1)
# minor_ticks = np.arange(0, 1, 0.02)

# ax.set_yticks(major_ticks)
# ax.set_yticks(minor_ticks, minor=True)
# ax.set_xticks(np.arange(10,110,10))
# ax.set_xlim(xmin=9,xmax=101)
# plt.legend(['LwF'])

ax.grid()
from sklearn.metrics import confusion_matrix
import seaborn as sns
fig,ax=plt.subplots(figsize=(7,5))
sns.heatmap((data[3][9]),cmap='terrain',ax=ax)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
